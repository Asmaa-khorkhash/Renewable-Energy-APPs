# %%
from Data import preprocess_data as pr
import numpy as np 
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import  Dense, Dropout, Input,Flatten

# %%
df = pd.read_csv('C:\\Users\\M4\\Desktop\\KAG_energydata_complete.csv',parse_dates=['date'], index_col= 'date')

# %%
df
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:00:00          60      30  19.890000  47.596667  19.200000
# 2016-01-11 17:10:00          60      30  19.890000  46.693333  19.200000
# 2016-01-11 17:20:00          50      30  19.890000  46.300000  19.200000
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 2016-01-11 17:40:00          60      40  19.890000  46.333333  19.200000
# ...                         ...     ...        ...        ...        ...
# 2016-05-27 17:20:00         100       0  25.566667  46.560000  25.890000
# 2016-05-27 17:30:00          90       0  25.500000  46.500000  25.754000
# 2016-05-27 17:40:00         270      10  25.500000  46.596667  25.628571
# 2016-05-27 17:50:00         420      10  25.500000  46.990000  25.414000
# 2016-05-27 18:00:00         430      10  25.500000  46.600000  25.264286
#
#                           RH_2         T3       RH_3         T4       RH_4  \
# date
# 2016-01-11 17:00:00  44.790000  19.790000  44.730000  19.000000  45.566667
# 2016-01-11 17:10:00  44.722500  19.790000  44.790000  19.000000  45.992500
# 2016-01-11 17:20:00  44.626667  19.790000  44.933333  18.926667  45.890000
# 2016-01-11 17:30:00  44.590000  19.790000  45.000000  18.890000  45.723333
# 2016-01-11 17:40:00  44.530000  19.790000  45.000000  18.890000  45.530000
# ...                        ...        ...        ...        ...        ...
# 2016-05-27 17:20:00  42.025714  27.200000  41.163333  24.700000  45.590000
# 2016-05-27 17:30:00  42.080000  27.133333  41.223333  24.700000  45.590000
# 2016-05-27 17:40:00  42.768571  27.050000  41.690000  24.700000  45.730000
# 2016-05-27 17:50:00  43.036000  26.890000  41.290000  24.700000  45.790000
# 2016-05-27 18:00:00  42.971429  26.823333  41.156667  24.700000  45.963333
#
#                      ...         T9     RH_9      T_out  Press_mm_hg  \
# date                 ...
# 2016-01-11 17:00:00  ...  17.033333  45.5300   6.600000        733.5
# 2016-01-11 17:10:00  ...  17.066667  45.5600   6.483333        733.6
# 2016-01-11 17:20:00  ...  17.000000  45.5000   6.366667        733.7
# 2016-01-11 17:30:00  ...  17.000000  45.4000   6.250000        733.8
# 2016-01-11 17:40:00  ...  17.000000  45.4000   6.133333        733.9
# ...                  ...        ...      ...        ...          ...
# 2016-05-27 17:20:00  ...  23.200000  46.7900  22.733333        755.2
# 2016-05-27 17:30:00  ...  23.200000  46.7900  22.600000        755.2
# 2016-05-27 17:40:00  ...  23.200000  46.7900  22.466667        755.2
# 2016-05-27 17:50:00  ...  23.200000  46.8175  22.333333        755.2
# 2016-05-27 18:00:00  ...  23.200000  46.8450  22.200000        755.2
#
#                         RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# date
# 2016-01-11 17:00:00  92.000000   7.000000   63.000000   5.300000  13.275433
# 2016-01-11 17:10:00  92.000000   6.666667   59.166667   5.200000  18.606195
# 2016-01-11 17:20:00  92.000000   6.333333   55.333333   5.100000  28.642668
# 2016-01-11 17:30:00  92.000000   6.000000   51.500000   5.000000  45.410389
# 2016-01-11 17:40:00  92.000000   5.666667   47.666667   4.900000  10.084097
# ...                        ...        ...         ...        ...        ...
# 2016-05-27 17:20:00  55.666667   3.333333   23.666667  13.333333  43.096812
# 2016-05-27 17:30:00  56.000000   3.500000   24.500000  13.300000  49.282940
# 2016-05-27 17:40:00  56.333333   3.666667   25.333333  13.266667  29.199117
# 2016-05-27 17:50:00  56.666667   3.833333   26.166667  13.233333   6.322784
# 2016-05-27 18:00:00  57.000000   4.000000   27.000000  13.200000  34.118851
#
#                            rv2
# date
# 2016-01-11 17:00:00  13.275433
# 2016-01-11 17:10:00  18.606195
# 2016-01-11 17:20:00  28.642668
# 2016-01-11 17:30:00  45.410389
# 2016-01-11 17:40:00  10.084097
# ...                        ...
# 2016-05-27 17:20:00  43.096812
# 2016-05-27 17:30:00  49.282940
# 2016-05-27 17:40:00  29.199117
# 2016-05-27 17:50:00   6.322784
# 2016-05-27 18:00:00  34.118851
#
# [19735 rows x 28 columns]

# %%
data = df.resample('D').sum()

# %%
df = df.resample('D').mean()
df.shape
# Out:
# (138, 28)

# %%
def train_test_split(df):
    
    # compute split point
    end_idx = df.shape[0]* 70 // 100
    
    train_data = df.iloc[1:end_idx, : ]
    test_data = df.iloc[end_idx:, :]
    
    return train_data, test_data

# Split the data into train and test
X_train, X_test = train_test_split(df)

# %%
X_test.shape , X_train.shape
# Out:
# ((42, 28), (95, 28))

# %%
from sklearn.preprocessing import MinMaxScaler
def scale_data(train, test):
    scaler = MinMaxScaler().fit(train)
    return scaler.transform(train), scaler.transform(test), scaler

# %%
X_train, X_test, scaler = scale_data(X_train, X_test)

# %%
def multivariate_splitter(df):

    input_features = []
    ouput_feature = []
    
    len_df = df.shape[0]
    
    for i in range(len_df):
        
        end_idx = i + 15
        
        if end_idx > len_df-15:
            break
            
        input_x , output_y = df[i:end_idx, 1:], df[end_idx: end_idx+15, 0]
        
        input_features.append(input_x)
        ouput_feature.append(output_y)
    
    return np.array(input_features), np.array(ouput_feature)

# %%
X_train, Y_train = multivariate_splitter(X_train)
X_test, Y_test = multivariate_splitter(X_test)

# %%
print('Shape of (training data) input features : %s and ouput feature %s' % (X_train.shape, Y_train.shape))
print('Shape of (testing data) input features : %s and ouput feature %s' % (X_test.shape, Y_test.shape))
# Out:
# Shape of (training data) input features : (66, 15, 27) and ouput feature (66, 15)
# Shape of (testing data) input features : (13, 15, 27) and ouput feature (13, 15)

# %%
import tensorflow as tf
from Energy_Models.FNN import FNN
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model = FNN(15,27,15).getModel()

# %%
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 15, 27)]          0
#
#  fnn_7 (FNN)                 (None, 15)                500751
#
# =================================================================
# Total params: 500,751
# Trainable params: 500,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss ='mae')
history = model.fit(X_train , Y_train, epochs=100, batch_size=16, verbose= 1,validation_split=0.2,callbacks=callback)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 46ms/step - loss: 0.3744 - val_loss: 0.3297
# Epoch 2/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3299 - val_loss: 0.3089
# Epoch 3/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3089 - val_loss: 0.2961
# Epoch 4/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2965 - val_loss: 0.2892
# Epoch 5/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2891 - val_loss: 0.2824
# Epoch 6/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2816 - val_loss: 0.2757
# Epoch 7/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2741 - val_loss: 0.2692
# Epoch 8/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2666 - val_loss: 0.2631
# Epoch 9/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2594 - val_loss: 0.2572
# Epoch 10/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2522 - val_loss: 0.2514
# Epoch 11/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2452 - val_loss: 0.2457
# Epoch 12/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2384 - val_loss: 0.2404
# Epoch 13/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2319 - val_loss: 0.2352
# Epoch 14/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2256 - val_loss: 0.2304
# Epoch 15/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2195 - val_loss: 0.2259
# Epoch 16/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2137 - val_loss: 0.2218
# Epoch 17/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2082 - val_loss: 0.2179
# Epoch 18/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.2029 - val_loss: 0.2144
# Epoch 19/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1980 - val_loss: 0.2111
# Epoch 20/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1933 - val_loss: 0.2080
# Epoch 21/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1888 - val_loss: 0.2052
# Epoch 22/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1846 - val_loss: 0.2027
# Epoch 23/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1808 - val_loss: 0.2004
# Epoch 24/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1771 - val_loss: 0.1985
# Epoch 25/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1739 - val_loss: 0.1969
# Epoch 26/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1707 - val_loss: 0.1956
# Epoch 27/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1678 - val_loss: 0.1944
# Epoch 28/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1651 - val_loss: 0.1933
# Epoch 29/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1625 - val_loss: 0.1923
# Epoch 30/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1601 - val_loss: 0.1914
# Epoch 31/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1579 - val_loss: 0.1906
# Epoch 32/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1557 - val_loss: 0.1899
# Epoch 33/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1538 - val_loss: 0.1893
# Epoch 34/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1520 - val_loss: 0.1888
# Epoch 35/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1503 - val_loss: 0.1883
# Epoch 36/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1488 - val_loss: 0.1880
# Epoch 37/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1473 - val_loss: 0.1877
# Epoch 38/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1459 - val_loss: 0.1875
# Epoch 39/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1448 - val_loss: 0.1872
# Epoch 40/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1437 - val_loss: 0.1870
# Epoch 41/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1427 - val_loss: 0.1868
# Epoch 42/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1419 - val_loss: 0.1866
# Epoch 43/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1410 - val_loss: 0.1865
# Epoch 44/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1403 - val_loss: 0.1864
# Epoch 45/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1396 - val_loss: 0.1863
# Epoch 46/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1390 - val_loss: 0.1864
# Epoch 47/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1384 - val_loss: 0.1865
# Epoch 48/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1378 - val_loss: 0.1867
# Epoch 49/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1373 - val_loss: 0.1869
# Epoch 50/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1369 - val_loss: 0.1871
# Epoch 51/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1364 - val_loss: 0.1873
# Epoch 52/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1361 - val_loss: 0.1875
# Epoch 53/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1357 - val_loss: 0.1877
# Epoch 54/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1354 - val_loss: 0.1879
# Epoch 55/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1350 - val_loss: 0.1881
# Epoch 56/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1348 - val_loss: 0.1883
# Epoch 57/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1345 - val_loss: 0.1885
# Epoch 58/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1343 - val_loss: 0.1888
# Epoch 59/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1340 - val_loss: 0.1890
# Epoch 60/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1338 - val_loss: 0.1892
# Epoch 61/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1337 - val_loss: 0.1895
# Epoch 62/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1336 - val_loss: 0.1896
# Epoch 63/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1334 - val_loss: 0.1898
# Epoch 64/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1333 - val_loss: 0.1900
# Epoch 65/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1332 - val_loss: 0.1901
# Epoch 66/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1331 - val_loss: 0.1902
# Epoch 67/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1331 - val_loss: 0.1903
# Epoch 68/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1330 - val_loss: 0.1904
# Epoch 69/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1329 - val_loss: 0.1904
# Epoch 70/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1328 - val_loss: 0.1904
# Epoch 71/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1327 - val_loss: 0.1904
# Epoch 72/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1327 - val_loss: 0.1903
# Epoch 73/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1327 - val_loss: 0.1904
# Epoch 74/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1326 - val_loss: 0.1905
# Epoch 75/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1326 - val_loss: 0.1906
# Epoch 76/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1326 - val_loss: 0.1907
# Epoch 77/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1326 - val_loss: 0.1907
# Epoch 78/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1325 - val_loss: 0.1907
# Epoch 79/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1325 - val_loss: 0.1908
# Epoch 80/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1325 - val_loss: 0.1909
# Epoch 81/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1325 - val_loss: 0.1910
# Epoch 82/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1324 - val_loss: 0.1911
# Epoch 83/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1324 - val_loss: 0.1912
# Epoch 84/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1324 - val_loss: 0.1912
# Epoch 85/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1324 - val_loss: 0.1913
# Epoch 86/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1324 - val_loss: 0.1913
# Epoch 87/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1324 - val_loss: 0.1913
# Epoch 88/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1324 - val_loss: 0.1913
# Epoch 89/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1324 - val_loss: 0.1913
# Epoch 90/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1324 - val_loss: 0.1914
# Epoch 91/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1324 - val_loss: 0.1914
# Epoch 92/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1324 - val_loss: 0.1914
# Epoch 93/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1324 - val_loss: 0.1914
# Epoch 94/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1324 - val_loss: 0.1914
# Epoch 95/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1324 - val_loss: 0.1914
# Epoch 96/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1324 - val_loss: 0.1913
# Epoch 97/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1324 - val_loss: 0.1913
# Epoch 98/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1324 - val_loss: 0.1913
# Epoch 99/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1324 - val_loss: 0.1913
# Epoch 100/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1324 - val_loss: 0.1912

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error, mean_absolute_percentage_error
def root_mean_squared_error(y_true, y_pred):    
    return np.sqrt(mean_squared_error(y_true, y_pred))
def root_mean_squared_log_error(real, predicted):
    sum=0.0
    for x in range(len(predicted)):
        if predicted[x]<0 or real[x]<0: # check for negative values
            continue
        p = np.log(predicted[x]+1)
        r = np.log(real[x]+1)
        sum = sum + (p - r)**2
    return (sum/len(predicted))**0.5
def print_metrics():
    print('Train   RMSE  value   : %.3f ' % root_mean_squared_error(Y_train, model.predict(X_train)))
    print('Train   MSE   value   : %.3f ' % mean_squared_error(Y_train, model.predict(X_train)))
    print('Train   R2    value   : %.3f ' % r2_score(Y_train,model.predict(X_train)))
    print('Train   MAPE  value   : %.3f ' % mean_absolute_percentage_error(Y_train, model.predict(X_train)))
    print('Train   MAE   value   : %.3f ' % mean_absolute_error(Y_train, model.predict(X_train)))
    print('---------------------------------------------')
    print('Test    RMSE  value   : %.3f ' % root_mean_squared_error(Y_test, model.predict(X_test)))
    print('Test    MSE   value   : %.3f ' % mean_squared_error(Y_test, model.predict(X_test)))
    print('Test    R2    value   : %.3f ' % r2_score(Y_test, model.predict(X_test)))
    print('Test    MAPE  value   : %.3f ' % mean_absolute_percentage_error(Y_test, model.predict(X_test)))
    print('Test    MAE   value   : %.3f ' % mean_absolute_error(Y_test, model.predict(X_test)))

# %%
print_metrics()
# Out:
# 3/3 [==============================] - 0s 0s/step
# Train   RMSE  value   : 0.201
# 3/3 [==============================] - 0s 8ms/step
# Train   MSE   value   : 0.040
# 3/3 [==============================] - 0s 0s/step
# Train   R2    value   : -0.032
# 3/3 [==============================] - 0s 3ms/step
# Train   MAPE  value   : 3359791718814.173
# 3/3 [==============================] - 0s 3ms/step
# Train   MAE   value   : 0.145
# ---------------------------------------------
# 1/1 [==============================] - 0s 16ms/step
# Test    RMSE  value   : 0.193
# 1/1 [==============================] - 0s 16ms/step
# Test    MSE   value   : 0.037
# 1/1 [==============================] - 0s 16ms/step
# Test    R2    value   : -0.026
# 1/1 [==============================] - 0s 16ms/step
# Test    MAPE  value   : 0.435
# 1/1 [==============================] - 0s 16ms/step
# Test    MAE   value   : 0.144

# %%
# Plot of loss vs epoch for train and test dataset
from matplotlib import pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

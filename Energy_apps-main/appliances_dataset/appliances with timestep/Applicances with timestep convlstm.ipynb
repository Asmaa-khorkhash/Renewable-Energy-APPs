# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r'C:\Users\FALCON\Desktop\term2\machinelearning\appliances_dataset_using_package\KAG_energydata_complete.csv',parse_dates=['date'], index_col= 'date')

# %%
df
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:00:00          60      30  19.890000  47.596667  19.200000
# 2016-01-11 17:10:00          60      30  19.890000  46.693333  19.200000
# 2016-01-11 17:20:00          50      30  19.890000  46.300000  19.200000
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 2016-01-11 17:40:00          60      40  19.890000  46.333333  19.200000
# ...                         ...     ...        ...        ...        ...
# 2016-05-27 17:20:00         100       0  25.566667  46.560000  25.890000
# 2016-05-27 17:30:00          90       0  25.500000  46.500000  25.754000
# 2016-05-27 17:40:00         270      10  25.500000  46.596667  25.628571
# 2016-05-27 17:50:00         420      10  25.500000  46.990000  25.414000
# 2016-05-27 18:00:00         430      10  25.500000  46.600000  25.264286
#
#                           RH_2         T3       RH_3         T4       RH_4  \
# date
# 2016-01-11 17:00:00  44.790000  19.790000  44.730000  19.000000  45.566667
# 2016-01-11 17:10:00  44.722500  19.790000  44.790000  19.000000  45.992500
# 2016-01-11 17:20:00  44.626667  19.790000  44.933333  18.926667  45.890000
# 2016-01-11 17:30:00  44.590000  19.790000  45.000000  18.890000  45.723333
# 2016-01-11 17:40:00  44.530000  19.790000  45.000000  18.890000  45.530000
# ...                        ...        ...        ...        ...        ...
# 2016-05-27 17:20:00  42.025714  27.200000  41.163333  24.700000  45.590000
# 2016-05-27 17:30:00  42.080000  27.133333  41.223333  24.700000  45.590000
# 2016-05-27 17:40:00  42.768571  27.050000  41.690000  24.700000  45.730000
# 2016-05-27 17:50:00  43.036000  26.890000  41.290000  24.700000  45.790000
# 2016-05-27 18:00:00  42.971429  26.823333  41.156667  24.700000  45.963333
#
#                      ...         T9     RH_9      T_out  Press_mm_hg  \
# date                 ...
# 2016-01-11 17:00:00  ...  17.033333  45.5300   6.600000        733.5
# 2016-01-11 17:10:00  ...  17.066667  45.5600   6.483333        733.6
# 2016-01-11 17:20:00  ...  17.000000  45.5000   6.366667        733.7
# 2016-01-11 17:30:00  ...  17.000000  45.4000   6.250000        733.8
# 2016-01-11 17:40:00  ...  17.000000  45.4000   6.133333        733.9
# ...                  ...        ...      ...        ...          ...
# 2016-05-27 17:20:00  ...  23.200000  46.7900  22.733333        755.2
# 2016-05-27 17:30:00  ...  23.200000  46.7900  22.600000        755.2
# 2016-05-27 17:40:00  ...  23.200000  46.7900  22.466667        755.2
# 2016-05-27 17:50:00  ...  23.200000  46.8175  22.333333        755.2
# 2016-05-27 18:00:00  ...  23.200000  46.8450  22.200000        755.2
#
#                         RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# date
# 2016-01-11 17:00:00  92.000000   7.000000   63.000000   5.300000  13.275433
# 2016-01-11 17:10:00  92.000000   6.666667   59.166667   5.200000  18.606195
# 2016-01-11 17:20:00  92.000000   6.333333   55.333333   5.100000  28.642668
# 2016-01-11 17:30:00  92.000000   6.000000   51.500000   5.000000  45.410389
# 2016-01-11 17:40:00  92.000000   5.666667   47.666667   4.900000  10.084097
# ...                        ...        ...         ...        ...        ...
# 2016-05-27 17:20:00  55.666667   3.333333   23.666667  13.333333  43.096812
# 2016-05-27 17:30:00  56.000000   3.500000   24.500000  13.300000  49.282940
# 2016-05-27 17:40:00  56.333333   3.666667   25.333333  13.266667  29.199117
# 2016-05-27 17:50:00  56.666667   3.833333   26.166667  13.233333   6.322784
# 2016-05-27 18:00:00  57.000000   4.000000   27.000000  13.200000  34.118851
#
#                            rv2
# date
# 2016-01-11 17:00:00  13.275433
# 2016-01-11 17:10:00  18.606195
# 2016-01-11 17:20:00  28.642668
# 2016-01-11 17:30:00  45.410389
# 2016-01-11 17:40:00  10.084097
# ...                        ...
# 2016-05-27 17:20:00  43.096812
# 2016-05-27 17:30:00  49.282940
# 2016-05-27 17:40:00  29.199117
# 2016-05-27 17:50:00   6.322784
# 2016-05-27 18:00:00  34.118851
#
# [19735 rows x 28 columns]

# %%
data = df.resample('D').sum()

# %%
df = df.resample('D').mean()
df.shape
# Out:
# (138, 28)

# %%
def train_test_split(df):
    
    # compute split point
    end_idx = df.shape[0]* 70 // 100
    
    train_data = df.iloc[1:end_idx, : ]
    test_data = df.iloc[end_idx:, :]
    
    return train_data, test_data

# Split the data into train and test
X_train, X_test = train_test_split(df)

# %%
X_test.shape , X_train.shape
# Out:
# ((42, 28), (95, 28))

# %%
from sklearn.preprocessing import MinMaxScaler
def scale_data(train, test):
    scaler = MinMaxScaler().fit(train)
    return scaler.transform(train), scaler.transform(test), scaler

# %%
X_train, X_test, scaler = scale_data(X_train, X_test)

# %%
def multivariate_splitter(df):

    input_features = []
    ouput_feature = []
    
    len_df = df.shape[0]
    
    for i in range(len_df):
        
        end_idx = i + 15
        
        if end_idx > len_df-15:
            break
            
        input_x , output_y = df[i:end_idx, 1:], df[end_idx: end_idx+15, 0]
        
        input_features.append(input_x)
        ouput_feature.append(output_y)
    
    return np.array(input_features), np.array(ouput_feature)

# %%
X_train, Y_train = multivariate_splitter(X_train)
X_test, Y_test = multivariate_splitter(X_test)

# %%
print('Shape of (training data) input features : %s and ouput feature %s' % (X_train.shape, Y_train.shape))
print('Shape of (testing data) input features : %s and ouput feature %s' % (X_test.shape, Y_test.shape))
# Out:
# Shape of (training data) input features : (66, 15, 27) and ouput feature (66, 15)
# Shape of (testing data) input features : (13, 15, 27) and ouput feature (13, 15)

# %%
import tensorflow as tf
from Energy_Models.ConvLstm import ConvLstm
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
n_steps, n_features = X_train.shape[1], X_train.shape[2]
convlstm_model = ConvLstm(n_steps,n_features,15).getModel()

# %%
X_train=X_train.reshape((X_train.shape[0],1,1,n_steps,X_train.shape[2]))
X_test=X_test.reshape((X_test.shape[0],1,1,n_steps,X_test.shape[2]))

# %%
convlstm_model.compile(optimizer='adam', loss ='mse')
history = convlstm_model.fit(X_train , Y_train, epochs=100, batch_size=16, verbose= 1,validation_split=0.2,callbacks=callback)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 28s 993ms/step - loss: 0.1929 - val_loss: 0.2111
# Epoch 2/100
# 4/4 [==============================] - 0s 109ms/step - loss: 0.1816 - val_loss: 0.1951
# Epoch 3/100
# 4/4 [==============================] - 0s 90ms/step - loss: 0.1629 - val_loss: 0.1693
# Epoch 4/100
# 4/4 [==============================] - 0s 100ms/step - loss: 0.1334 - val_loss: 0.1320
# Epoch 5/100
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0918 - val_loss: 0.0909
# Epoch 6/100
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0559 - val_loss: 0.0835
# Epoch 7/100
# 4/4 [==============================] - 0s 119ms/step - loss: 0.0549 - val_loss: 0.0753
# Epoch 8/100
# 4/4 [==============================] - 1s 163ms/step - loss: 0.0414 - val_loss: 0.0672
# Epoch 9/100
# 4/4 [==============================] - 0s 132ms/step - loss: 0.0361 - val_loss: 0.0669
# Epoch 10/100
# 4/4 [==============================] - 0s 127ms/step - loss: 0.0359 - val_loss: 0.0653
# Epoch 11/100
# 4/4 [==============================] - 0s 101ms/step - loss: 0.0340 - val_loss: 0.0638
# Epoch 12/100
# 4/4 [==============================] - 0s 103ms/step - loss: 0.0331 - val_loss: 0.0643
# Epoch 13/100
# 4/4 [==============================] - 0s 94ms/step - loss: 0.0335 - val_loss: 0.0642
# Epoch 14/100
# 4/4 [==============================] - 0s 108ms/step - loss: 0.0333 - val_loss: 0.0634
# Epoch 15/100
# 4/4 [==============================] - 0s 101ms/step - loss: 0.0330 - val_loss: 0.0632
# Epoch 16/100
# 4/4 [==============================] - 0s 93ms/step - loss: 0.0329 - val_loss: 0.0633
# Epoch 17/100
# 4/4 [==============================] - 0s 99ms/step - loss: 0.0328 - val_loss: 0.0632
# Epoch 18/100
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0327 - val_loss: 0.0632
# Epoch 19/100
# 4/4 [==============================] - 0s 91ms/step - loss: 0.0326 - val_loss: 0.0632
# Epoch 20/100
# 4/4 [==============================] - 0s 134ms/step - loss: 0.0327 - val_loss: 0.0632
# Epoch 21/100
# 4/4 [==============================] - 0s 85ms/step - loss: 0.0327 - val_loss: 0.0633
# Epoch 22/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0328 - val_loss: 0.0633
# Epoch 23/100
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0327 - val_loss: 0.0634
# Epoch 24/100
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0327 - val_loss: 0.0633
# Epoch 25/100
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0326 - val_loss: 0.0632
# Epoch 26/100
# 4/4 [==============================] - 0s 94ms/step - loss: 0.0326 - val_loss: 0.0631
# Epoch 27/100
# 4/4 [==============================] - 0s 81ms/step - loss: 0.0326 - val_loss: 0.0630
# Epoch 28/100
# 4/4 [==============================] - 0s 97ms/step - loss: 0.0327 - val_loss: 0.0630
# Epoch 29/100
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0328 - val_loss: 0.0631
# Epoch 30/100
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0328 - val_loss: 0.0631
# Epoch 31/100
# 4/4 [==============================] - 0s 129ms/step - loss: 0.0327 - val_loss: 0.0631
# Epoch 32/100
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0327 - val_loss: 0.0633
# Epoch 33/100
# 4/4 [==============================] - 0s 100ms/step - loss: 0.0326 - val_loss: 0.0635
# Epoch 34/100
# 4/4 [==============================] - 0s 91ms/step - loss: 0.0327 - val_loss: 0.0634
# Epoch 35/100
# 4/4 [==============================] - 0s 95ms/step - loss: 0.0327 - val_loss: 0.0633
# Epoch 36/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0327 - val_loss: 0.0632

# %%
y_pred_train = convlstm_model.predict(X_train)
y_pred_test  = convlstm_model.predict(X_test)
# Out:
# 3/3 [==============================] - 5s 40ms/step
# 1/1 [==============================] - 0s 44ms/step

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error, mean_absolute_percentage_error

def root_mean_squared_error(y_true, y_pred):    
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
print('Train RMSE value for LSTM Model  : %.3f ' % root_mean_squared_error(Y_train, y_pred_train))
print('Train MSE value for LSTM Model  : %.3f ' % mean_squared_error(Y_train, y_pred_train))
print('Train R2 value for LSTM Model  : %.3f ' % r2_score(Y_train, y_pred_train))
print('Train MAPE value for LSTM Model  : %.3f ' % mean_absolute_percentage_error(Y_train, y_pred_train))
print('Train RMLSE value for LSTM Model  : %.3f ' % mean_squared_log_error(Y_train, y_pred_train))
print('Train MAE value for LSTM Model  : %.3f ' % mean_absolute_error(Y_train, y_pred_train))
print('---------------------------------------------')
print('Test RMSE value for LSTM Model  : %.3f ' % root_mean_squared_error(Y_test, y_pred_test))
print('Test MSE value for LSTM Model  : %.3f ' % mean_squared_error(Y_test, y_pred_test))
print('Test R2 value for LSTM Model  : %.3f ' % r2_score(Y_test, y_pred_test))
print('Test MAPE value for LSTM Model  : %.3f ' % mean_absolute_percentage_error(Y_test, y_pred_test))
print('Test RMLSE value for LSTM Model  : %.3f ' % mean_squared_log_error(Y_test, y_pred_test))
print('Test MAE value for LSTM Model  : %.3f ' % mean_absolute_error(Y_test, y_pred_test))
# Out:
# Train RMSE value for LSTM Model  : 0.198
# Train MSE value for LSTM Model  : 0.039
# Train R2 value for LSTM Model  : -0.003
# Train MAPE value for LSTM Model  : 3579274444502.606
# Train RMLSE value for LSTM Model  : 0.018
# Train MAE value for LSTM Model  : 0.152
# ---------------------------------------------
# Test RMSE value for LSTM Model  : 0.196
# Test MSE value for LSTM Model  : 0.038
# Test R2 value for LSTM Model  : -0.063
# Test MAPE value for LSTM Model  : 0.488
# Test RMLSE value for LSTM Model  : 0.018
# Test MAE value for LSTM Model  : 0.148

# %%
# Plot of loss vs epoch for train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:\\Users\\M4\\Desktop\\KAG_energydata_complete.csv',parse_dates=['date'], index_col= 'date')

# %%
df
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:00:00          60      30  19.890000  47.596667  19.200000
# 2016-01-11 17:10:00          60      30  19.890000  46.693333  19.200000
# 2016-01-11 17:20:00          50      30  19.890000  46.300000  19.200000
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 2016-01-11 17:40:00          60      40  19.890000  46.333333  19.200000
# ...                         ...     ...        ...        ...        ...
# 2016-05-27 17:20:00         100       0  25.566667  46.560000  25.890000
# 2016-05-27 17:30:00          90       0  25.500000  46.500000  25.754000
# 2016-05-27 17:40:00         270      10  25.500000  46.596667  25.628571
# 2016-05-27 17:50:00         420      10  25.500000  46.990000  25.414000
# 2016-05-27 18:00:00         430      10  25.500000  46.600000  25.264286
#
#                           RH_2         T3       RH_3         T4       RH_4  \
# date
# 2016-01-11 17:00:00  44.790000  19.790000  44.730000  19.000000  45.566667
# 2016-01-11 17:10:00  44.722500  19.790000  44.790000  19.000000  45.992500
# 2016-01-11 17:20:00  44.626667  19.790000  44.933333  18.926667  45.890000
# 2016-01-11 17:30:00  44.590000  19.790000  45.000000  18.890000  45.723333
# 2016-01-11 17:40:00  44.530000  19.790000  45.000000  18.890000  45.530000
# ...                        ...        ...        ...        ...        ...
# 2016-05-27 17:20:00  42.025714  27.200000  41.163333  24.700000  45.590000
# 2016-05-27 17:30:00  42.080000  27.133333  41.223333  24.700000  45.590000
# 2016-05-27 17:40:00  42.768571  27.050000  41.690000  24.700000  45.730000
# 2016-05-27 17:50:00  43.036000  26.890000  41.290000  24.700000  45.790000
# 2016-05-27 18:00:00  42.971429  26.823333  41.156667  24.700000  45.963333
#
#                      ...         T9     RH_9      T_out  Press_mm_hg  \
# date                 ...
# 2016-01-11 17:00:00  ...  17.033333  45.5300   6.600000        733.5
# 2016-01-11 17:10:00  ...  17.066667  45.5600   6.483333        733.6
# 2016-01-11 17:20:00  ...  17.000000  45.5000   6.366667        733.7
# 2016-01-11 17:30:00  ...  17.000000  45.4000   6.250000        733.8
# 2016-01-11 17:40:00  ...  17.000000  45.4000   6.133333        733.9
# ...                  ...        ...      ...        ...          ...
# 2016-05-27 17:20:00  ...  23.200000  46.7900  22.733333        755.2
# 2016-05-27 17:30:00  ...  23.200000  46.7900  22.600000        755.2
# 2016-05-27 17:40:00  ...  23.200000  46.7900  22.466667        755.2
# 2016-05-27 17:50:00  ...  23.200000  46.8175  22.333333        755.2
# 2016-05-27 18:00:00  ...  23.200000  46.8450  22.200000        755.2
#
#                         RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# date
# 2016-01-11 17:00:00  92.000000   7.000000   63.000000   5.300000  13.275433
# 2016-01-11 17:10:00  92.000000   6.666667   59.166667   5.200000  18.606195
# 2016-01-11 17:20:00  92.000000   6.333333   55.333333   5.100000  28.642668
# 2016-01-11 17:30:00  92.000000   6.000000   51.500000   5.000000  45.410389
# 2016-01-11 17:40:00  92.000000   5.666667   47.666667   4.900000  10.084097
# ...                        ...        ...         ...        ...        ...
# 2016-05-27 17:20:00  55.666667   3.333333   23.666667  13.333333  43.096812
# 2016-05-27 17:30:00  56.000000   3.500000   24.500000  13.300000  49.282940
# 2016-05-27 17:40:00  56.333333   3.666667   25.333333  13.266667  29.199117
# 2016-05-27 17:50:00  56.666667   3.833333   26.166667  13.233333   6.322784
# 2016-05-27 18:00:00  57.000000   4.000000   27.000000  13.200000  34.118851
#
#                            rv2
# date
# 2016-01-11 17:00:00  13.275433
# 2016-01-11 17:10:00  18.606195
# 2016-01-11 17:20:00  28.642668
# 2016-01-11 17:30:00  45.410389
# 2016-01-11 17:40:00  10.084097
# ...                        ...
# 2016-05-27 17:20:00  43.096812
# 2016-05-27 17:30:00  49.282940
# 2016-05-27 17:40:00  29.199117
# 2016-05-27 17:50:00   6.322784
# 2016-05-27 18:00:00  34.118851
#
# [19735 rows x 28 columns]

# %%
df = df.resample('D').mean()
df.shape
# Out:
# (138, 28)

# %%
def train_test_split(df):
    
    # compute split point
    end_idx = df.shape[0]* 70 // 100
    
    train_data = df.iloc[1:end_idx, : ]
    test_data = df.iloc[end_idx:, :]
    
    return train_data, test_data

# Split the data into train and test
X_train, X_test = train_test_split(df)

# %%
X_test.shape , X_train.shape
# Out:
# ((42, 28), (95, 28))

# %%
from sklearn.preprocessing import MinMaxScaler
def scale_data(train, test):
    scaler = MinMaxScaler().fit(train)
    return scaler.transform(train), scaler.transform(test), scaler

# %%
X_train, X_test, scaler = scale_data(X_train, X_test)

# %%
def multivariate_splitter(df):

    input_features = []
    ouput_feature = []
    
    len_df = df.shape[0]
    
    for i in range(len_df):
        
        end_idx = i + 15
        
        if end_idx > len_df-15:
            break
            
        input_x , output_y = df[i:end_idx, 1:], df[end_idx: end_idx+15, 0]
        
        input_features.append(input_x)
        ouput_feature.append(output_y)
    
    return np.array(input_features), np.array(ouput_feature)

# %%
X_train, Y_train = multivariate_splitter(X_train)
X_test, Y_test = multivariate_splitter(X_test)

# %%
print('Shape of (training data) input features : %s and ouput feature %s' % (X_train.shape, Y_train.shape))
print('Shape of (testing data) input features : %s and ouput feature %s' % (X_test.shape, Y_test.shape))
# Out:
# Shape of (training data) input features : (66, 15, 27) and ouput feature (66, 15)
# Shape of (testing data) input features : (13, 15, 27) and ouput feature (13, 15)

# %%
import tensorflow as tf
from Energy_Models.bert import Bert
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model = Bert(15,27,15).getModel()

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 15, 27)]     0           []
#
#  token_embedding_9 (TokenEmbedd  (None, 15, 32)      864         ['input_5[0][0]']
#  ing)
#
#  encoder_9 (Encoder)            (None, 15, 32)       5312        ['token_embedding_9[0][0]']
#
#  tf.__operators__.getitem_4 (Sl  (None, 32)          0           ['encoder_9[0][0]']
#  icingOpLambda)
#
#  dropout_18 (Dropout)           (None, 32)           0           ['tf.__operators__.getitem_4[0][0
#                                                                  ]']
#
#  dense_28 (Dense)               (None, 512)          16896       ['dropout_18[0][0]']
#
#  dropout_19 (Dropout)           multiple             0           ['dense_28[0][0]',
#                                                                   'dense_29[0][0]']
#
#  dense_29 (Dense)               (None, 1024)         525312      ['dropout_19[0][0]']
#
#  dense_27 (Dense)               (None, 15)           15375       ['dropout_19[1][0]']
#
# ==================================================================================================
# Total params: 563,759
# Trainable params: 563,759
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss ='mse')
history = model.fit(X_train , Y_train, epochs=200, batch_size=64, verbose= 1,validation_split=0.3,callbacks=callback)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0482 - val_loss: 0.0599
# Epoch 2/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0330 - val_loss: 0.0595
# Epoch 3/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0345 - val_loss: 0.0601
# Epoch 4/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0355 - val_loss: 0.0594
# Epoch 5/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0338 - val_loss: 0.0589
# Epoch 6/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0321 - val_loss: 0.0591
# Epoch 7/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0323 - val_loss: 0.0598
# Epoch 8/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0313 - val_loss: 0.0604
# Epoch 9/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0313 - val_loss: 0.0609
# Epoch 10/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0325 - val_loss: 0.0611
# Epoch 11/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0312 - val_loss: 0.0610
# Epoch 12/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0308 - val_loss: 0.0608
# Epoch 13/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0305 - val_loss: 0.0606
# Epoch 14/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0309 - val_loss: 0.0604
# Epoch 15/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0307 - val_loss: 0.0602
# Epoch 16/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0302 - val_loss: 0.0602
# Epoch 17/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0294 - val_loss: 0.0602
# Epoch 18/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0302 - val_loss: 0.0603
# Epoch 19/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0296 - val_loss: 0.0606
# Epoch 20/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0296 - val_loss: 0.0609
# Epoch 21/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0298 - val_loss: 0.0612
# Epoch 22/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0295 - val_loss: 0.0616
# Epoch 23/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0299 - val_loss: 0.0621
# Epoch 24/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0300 - val_loss: 0.0626
# Epoch 25/200
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0297 - val_loss: 0.0630
# Epoch 26/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0290 - val_loss: 0.0635
# Epoch 27/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0294 - val_loss: 0.0638
# Epoch 28/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0293 - val_loss: 0.0642
# Epoch 29/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0284 - val_loss: 0.0645
# Epoch 30/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0283 - val_loss: 0.0649
# Epoch 31/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0287 - val_loss: 0.0653
# Epoch 32/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0277 - val_loss: 0.0658
# Epoch 33/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0276 - val_loss: 0.0664
# Epoch 34/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0282 - val_loss: 0.0669
# Epoch 35/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0271 - val_loss: 0.0677
# Epoch 36/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0269 - val_loss: 0.0684
# Epoch 37/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0282 - val_loss: 0.0691
# Epoch 38/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0274 - val_loss: 0.0696
# Epoch 39/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0272 - val_loss: 0.0701
# Epoch 40/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0284 - val_loss: 0.0708
# Epoch 41/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0271 - val_loss: 0.0717
# Epoch 42/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0259 - val_loss: 0.0729
# Epoch 43/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0265 - val_loss: 0.0737
# Epoch 44/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0255 - val_loss: 0.0746
# Epoch 45/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0258 - val_loss: 0.0753
# Epoch 46/200
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0254 - val_loss: 0.0759
# Epoch 47/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0255 - val_loss: 0.0768
# Epoch 48/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0240 - val_loss: 0.0778
# Epoch 49/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0238 - val_loss: 0.0790
# Epoch 50/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0240 - val_loss: 0.0800
# Epoch 51/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0227 - val_loss: 0.0806
# Epoch 52/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0229 - val_loss: 0.0814
# Epoch 53/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0232 - val_loss: 0.0827
# Epoch 54/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0230 - val_loss: 0.0830
# Epoch 55/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0235 - val_loss: 0.0829
# Epoch 56/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0229 - val_loss: 0.0834
# Epoch 57/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0214 - val_loss: 0.0839
# Epoch 58/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0220 - val_loss: 0.0845
# Epoch 59/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0217 - val_loss: 0.0843
# Epoch 60/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0211 - val_loss: 0.0837
# Epoch 61/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0209 - val_loss: 0.0834
# Epoch 62/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0203 - val_loss: 0.0831
# Epoch 63/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0206 - val_loss: 0.0831
# Epoch 64/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0194 - val_loss: 0.0835
# Epoch 65/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0195 - val_loss: 0.0836
# Epoch 66/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0200 - val_loss: 0.0835
# Epoch 67/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0183 - val_loss: 0.0836
# Epoch 68/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0199 - val_loss: 0.0836
# Epoch 69/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0170 - val_loss: 0.0841
# Epoch 70/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0176 - val_loss: 0.0848
# Epoch 71/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0175 - val_loss: 0.0849
# Epoch 72/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0173 - val_loss: 0.0844
# Epoch 73/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0155 - val_loss: 0.0841
# Epoch 74/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0169 - val_loss: 0.0845
# Epoch 75/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0161 - val_loss: 0.0857
# Epoch 76/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0163 - val_loss: 0.0864
# Epoch 77/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0158 - val_loss: 0.0867
# Epoch 78/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0150 - val_loss: 0.0875
# Epoch 79/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0161 - val_loss: 0.0883
# Epoch 80/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0155 - val_loss: 0.0891
# Epoch 81/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0150 - val_loss: 0.0895
# Epoch 82/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0149 - val_loss: 0.0899
# Epoch 83/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0143 - val_loss: 0.0904
# Epoch 84/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0137 - val_loss: 0.0913
# Epoch 85/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0132 - val_loss: 0.0923
# Epoch 86/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0134 - val_loss: 0.0932
# Epoch 87/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0143 - val_loss: 0.0929
# Epoch 88/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0121 - val_loss: 0.0925
# Epoch 89/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0122 - val_loss: 0.0922
# Epoch 90/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0126 - val_loss: 0.0931
# Epoch 91/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0129 - val_loss: 0.0942
# Epoch 92/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0139 - val_loss: 0.0956
# Epoch 93/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0114 - val_loss: 0.0964
# Epoch 94/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0130 - val_loss: 0.0969
# Epoch 95/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0121 - val_loss: 0.0968
# Epoch 96/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0113 - val_loss: 0.0962
# Epoch 97/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0128 - val_loss: 0.0958
# Epoch 98/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0118 - val_loss: 0.0965
# Epoch 99/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0124 - val_loss: 0.0973
# Epoch 100/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0108 - val_loss: 0.0979
# Epoch 101/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0100 - val_loss: 0.0977
# Epoch 102/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0104 - val_loss: 0.0969
# Epoch 103/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0112 - val_loss: 0.0948
# Epoch 104/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0102 - val_loss: 0.0926
# Epoch 105/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0105 - val_loss: 0.0910
# Epoch 106/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0105 - val_loss: 0.0909
# Epoch 107/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0105 - val_loss: 0.0913
# Epoch 108/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0102 - val_loss: 0.0919
# Epoch 109/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0097 - val_loss: 0.0919
# Epoch 110/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0097 - val_loss: 0.0910
# Epoch 111/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0090 - val_loss: 0.0901
# Epoch 112/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0098 - val_loss: 0.0894
# Epoch 113/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0089 - val_loss: 0.0895
# Epoch 114/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0105 - val_loss: 0.0902
# Epoch 115/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0090 - val_loss: 0.0915
# Epoch 116/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0095 - val_loss: 0.0926
# Epoch 117/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0099 - val_loss: 0.0931
# Epoch 118/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0094 - val_loss: 0.0929
# Epoch 119/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0086 - val_loss: 0.0927
# Epoch 120/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0076 - val_loss: 0.0924
# Epoch 121/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0079 - val_loss: 0.0931
# Epoch 122/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0089 - val_loss: 0.0941
# Epoch 123/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0083 - val_loss: 0.0956
# Epoch 124/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0071 - val_loss: 0.0968
# Epoch 125/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0079 - val_loss: 0.0972
# Epoch 126/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0083 - val_loss: 0.0970
# Epoch 127/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0072 - val_loss: 0.0964
# Epoch 128/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0076 - val_loss: 0.0955
# Epoch 129/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0093 - val_loss: 0.0950
# Epoch 130/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0075 - val_loss: 0.0944
# Epoch 131/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0078 - val_loss: 0.0945
# Epoch 132/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0078 - val_loss: 0.0953
# Epoch 133/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0064 - val_loss: 0.0962
# Epoch 134/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0067 - val_loss: 0.0966
# Epoch 135/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0067 - val_loss: 0.0961
# Epoch 136/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0084 - val_loss: 0.0948
# Epoch 137/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0068 - val_loss: 0.0935
# Epoch 138/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0085 - val_loss: 0.0929
# Epoch 139/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0065 - val_loss: 0.0925
# Epoch 140/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0073 - val_loss: 0.0926
# Epoch 141/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0063 - val_loss: 0.0930
# Epoch 142/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0065 - val_loss: 0.0930
# Epoch 143/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0064 - val_loss: 0.0928
# Epoch 144/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0056 - val_loss: 0.0927
# Epoch 145/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0063 - val_loss: 0.0925
# Epoch 146/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0068 - val_loss: 0.0923
# Epoch 147/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0062 - val_loss: 0.0922
# Epoch 148/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0069 - val_loss: 0.0923
# Epoch 149/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0061 - val_loss: 0.0926
# Epoch 150/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0064 - val_loss: 0.0933
# Epoch 151/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0068 - val_loss: 0.0934
# Epoch 152/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0068 - val_loss: 0.0941
# Epoch 153/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0065 - val_loss: 0.0941
# Epoch 154/200
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0056 - val_loss: 0.0937
# Epoch 155/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0064 - val_loss: 0.0929
# Epoch 156/200
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0059 - val_loss: 0.0916
# Epoch 157/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0058 - val_loss: 0.0908
# Epoch 158/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0054 - val_loss: 0.0905
# Epoch 159/200
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0900
# Epoch 160/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0058 - val_loss: 0.0893
# Epoch 161/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0057 - val_loss: 0.0888
# Epoch 162/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0060 - val_loss: 0.0886
# Epoch 163/200
# 1/1 [==============================] - 0s 45ms/step - loss: 0.0052 - val_loss: 0.0885
# Epoch 164/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0059 - val_loss: 0.0883
# Epoch 165/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0056 - val_loss: 0.0884
# Epoch 166/200
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0056 - val_loss: 0.0887
# Epoch 167/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0054 - val_loss: 0.0890
# Epoch 168/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0044 - val_loss: 0.0894
# Epoch 169/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0052 - val_loss: 0.0897
# Epoch 170/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0058 - val_loss: 0.0897
# Epoch 171/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0050 - val_loss: 0.0900
# Epoch 172/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0048 - val_loss: 0.0902
# Epoch 173/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0046 - val_loss: 0.0905
# Epoch 174/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0054 - val_loss: 0.0903
# Epoch 175/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0057 - val_loss: 0.0899
# Epoch 176/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0049 - val_loss: 0.0896
# Epoch 177/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0051 - val_loss: 0.0897
# Epoch 178/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0047 - val_loss: 0.0897

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error, mean_absolute_percentage_error
def root_mean_squared_error(y_true, y_pred):    
    return np.sqrt(mean_squared_error(y_true, y_pred))
def root_mean_squared_log_error(real, predicted):
    sum=0.0
    for x in range(len(predicted)):
        if predicted[x]<0 or real[x]<0: # check for negative values
            continue
        p = np.log(predicted[x]+1)
        r = np.log(real[x]+1)
        sum = sum + (p - r)**2
    return (sum/len(predicted))**0.5
def print_metrics():
    print('Train   RMSE  value   : %.3f ' % root_mean_squared_error(Y_train, model.predict(X_train)))
    print('Train   MSE   value   : %.3f ' % mean_squared_error(Y_train, model.predict(X_train)))
    print('Train   R2    value   : %.3f ' % r2_score(Y_train,model.predict(X_train)))
    print('Train   MAPE  value   : %.3f ' % mean_absolute_percentage_error(Y_train, model.predict(X_train)))
    print('Train   MAE   value   : %.3f ' % mean_absolute_error(Y_train, model.predict(X_train)))
    print('---------------------------------------------')
    print('Test    RMSE  value   : %.3f ' % root_mean_squared_error(Y_test, model.predict(X_test)))
    print('Test    MSE   value   : %.3f ' % mean_squared_error(Y_test, model.predict(X_test)))
    print('Test    R2    value   : %.3f ' % r2_score(Y_test, model.predict(X_test)))
    print('Test    MAPE  value   : %.3f ' % mean_absolute_percentage_error(Y_test, model.predict(X_test)))
    print('Test    MAE   value   : %.3f ' % mean_absolute_error(Y_test, model.predict(X_test)))

# %%
print_metrics()
# Out:
# 3/3 [==============================] - 0s 4ms/step
# Train   RMSE  value   : 0.167
# 3/3 [==============================] - 0s 3ms/step
# Train   MSE   value   : 0.028
# 3/3 [==============================] - 0s 3ms/step
# Train   R2    value   : 0.280
# 3/3 [==============================] - 0s 3ms/step
# Train   MAPE  value   : 534268952212.227
# 3/3 [==============================] - 0s 3ms/step
# Train   MAE   value   : 0.090
# ---------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# Test    RMSE  value   : 0.238
# 1/1 [==============================] - 0s 21ms/step
# Test    MSE   value   : 0.057
# 1/1 [==============================] - 0s 21ms/step
# Test    R2    value   : -0.585
# 1/1 [==============================] - 0s 20ms/step
# Test    MAPE  value   : 0.630
# 1/1 [==============================] - 0s 20ms/step
# Test    MAE   value   : 0.190

# %%
# Plot of loss vs epoch for train and test dataset
from matplotlib import pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

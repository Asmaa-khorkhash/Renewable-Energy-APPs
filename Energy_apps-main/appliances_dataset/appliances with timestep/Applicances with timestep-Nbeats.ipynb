# %%
import numpy as np 
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('C:\\Users\\M4\\Desktop\\KAG_energydata_complete.csv',parse_dates=['date'], index_col= 'date')

# %%
df
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:00:00          60      30  19.890000  47.596667  19.200000
# 2016-01-11 17:10:00          60      30  19.890000  46.693333  19.200000
# 2016-01-11 17:20:00          50      30  19.890000  46.300000  19.200000
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 2016-01-11 17:40:00          60      40  19.890000  46.333333  19.200000
# ...                         ...     ...        ...        ...        ...
# 2016-05-27 17:20:00         100       0  25.566667  46.560000  25.890000
# 2016-05-27 17:30:00          90       0  25.500000  46.500000  25.754000
# 2016-05-27 17:40:00         270      10  25.500000  46.596667  25.628571
# 2016-05-27 17:50:00         420      10  25.500000  46.990000  25.414000
# 2016-05-27 18:00:00         430      10  25.500000  46.600000  25.264286
#
#                           RH_2         T3       RH_3         T4       RH_4  \
# date
# 2016-01-11 17:00:00  44.790000  19.790000  44.730000  19.000000  45.566667
# 2016-01-11 17:10:00  44.722500  19.790000  44.790000  19.000000  45.992500
# 2016-01-11 17:20:00  44.626667  19.790000  44.933333  18.926667  45.890000
# 2016-01-11 17:30:00  44.590000  19.790000  45.000000  18.890000  45.723333
# 2016-01-11 17:40:00  44.530000  19.790000  45.000000  18.890000  45.530000
# ...                        ...        ...        ...        ...        ...
# 2016-05-27 17:20:00  42.025714  27.200000  41.163333  24.700000  45.590000
# 2016-05-27 17:30:00  42.080000  27.133333  41.223333  24.700000  45.590000
# 2016-05-27 17:40:00  42.768571  27.050000  41.690000  24.700000  45.730000
# 2016-05-27 17:50:00  43.036000  26.890000  41.290000  24.700000  45.790000
# 2016-05-27 18:00:00  42.971429  26.823333  41.156667  24.700000  45.963333
#
#                      ...         T9     RH_9      T_out  Press_mm_hg  \
# date                 ...
# 2016-01-11 17:00:00  ...  17.033333  45.5300   6.600000        733.5
# 2016-01-11 17:10:00  ...  17.066667  45.5600   6.483333        733.6
# 2016-01-11 17:20:00  ...  17.000000  45.5000   6.366667        733.7
# 2016-01-11 17:30:00  ...  17.000000  45.4000   6.250000        733.8
# 2016-01-11 17:40:00  ...  17.000000  45.4000   6.133333        733.9
# ...                  ...        ...      ...        ...          ...
# 2016-05-27 17:20:00  ...  23.200000  46.7900  22.733333        755.2
# 2016-05-27 17:30:00  ...  23.200000  46.7900  22.600000        755.2
# 2016-05-27 17:40:00  ...  23.200000  46.7900  22.466667        755.2
# 2016-05-27 17:50:00  ...  23.200000  46.8175  22.333333        755.2
# 2016-05-27 18:00:00  ...  23.200000  46.8450  22.200000        755.2
#
#                         RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# date
# 2016-01-11 17:00:00  92.000000   7.000000   63.000000   5.300000  13.275433
# 2016-01-11 17:10:00  92.000000   6.666667   59.166667   5.200000  18.606195
# 2016-01-11 17:20:00  92.000000   6.333333   55.333333   5.100000  28.642668
# 2016-01-11 17:30:00  92.000000   6.000000   51.500000   5.000000  45.410389
# 2016-01-11 17:40:00  92.000000   5.666667   47.666667   4.900000  10.084097
# ...                        ...        ...         ...        ...        ...
# 2016-05-27 17:20:00  55.666667   3.333333   23.666667  13.333333  43.096812
# 2016-05-27 17:30:00  56.000000   3.500000   24.500000  13.300000  49.282940
# 2016-05-27 17:40:00  56.333333   3.666667   25.333333  13.266667  29.199117
# 2016-05-27 17:50:00  56.666667   3.833333   26.166667  13.233333   6.322784
# 2016-05-27 18:00:00  57.000000   4.000000   27.000000  13.200000  34.118851
#
#                            rv2
# date
# 2016-01-11 17:00:00  13.275433
# 2016-01-11 17:10:00  18.606195
# 2016-01-11 17:20:00  28.642668
# 2016-01-11 17:30:00  45.410389
# 2016-01-11 17:40:00  10.084097
# ...                        ...
# 2016-05-27 17:20:00  43.096812
# 2016-05-27 17:30:00  49.282940
# 2016-05-27 17:40:00  29.199117
# 2016-05-27 17:50:00   6.322784
# 2016-05-27 18:00:00  34.118851
#
# [19735 rows x 28 columns]

# %%
data = df.resample('D').sum()

# %%
df = df.resample('D').mean()
df.shape
# Out:
# (138, 28)

# %%
def train_test_split(df):
    
    # compute split point
    end_idx = df.shape[0]* 70 // 100
    
    train_data = df.iloc[1:end_idx, : ]
    test_data = df.iloc[end_idx:, :]
    
    return train_data, test_data

# Split the data into train and test
X_train, X_test = train_test_split(df)

# %%
X_test.shape , X_train.shape
# Out:
# ((42, 28), (95, 28))

# %%
from sklearn.preprocessing import MinMaxScaler
def scale_data(train, test):
    scaler = MinMaxScaler().fit(train)
    return scaler.transform(train), scaler.transform(test), scaler

# %%
X_train, X_test, scaler = scale_data(X_train, X_test)

# %%
def multivariate_splitter(df):

    input_features = []
    ouput_feature = []
    
    len_df = df.shape[0]
    
    for i in range(len_df):
        
        end_idx = i + 15
        
        if end_idx > len_df-15:
            break
            
        input_x , output_y = df[i:end_idx, 1:], df[end_idx: end_idx+15, 0]
        
        input_features.append(input_x)
        ouput_feature.append(output_y)
    
    return np.array(input_features), np.array(ouput_feature)

# %%
X_train, Y_train = multivariate_splitter(X_train)
X_test, Y_test = multivariate_splitter(X_test)

# %%
print('Shape of (training data) input features : %s and ouput feature %s' % (X_train.shape, Y_train.shape))
print('Shape of (testing data) input features : %s and ouput feature %s' % (X_test.shape, Y_test.shape))
# Out:
# Shape of (training data) input features : (66, 15, 27) and ouput feature (66, 15)
# Shape of (testing data) input features : (13, 15, 27) and ouput feature (13, 15)

# %%
import tensorflow as tf
from Energy_Models.NBEATS import NBeatsNet
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model = NBeatsNet(15,27,15)

# %%
model.summary()
# Out:
# Model: "forecast"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_variable (InputLayer)    [(None, 15, 27)]     0           []
#
#  lambda (Lambda)                (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_1 (Lambda)              (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_2 (Lambda)              (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_3 (Lambda)              (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_4 (Lambda)              (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_5 (Lambda)              (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_6 (Lambda)              (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_7 (Lambda)              (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_8 (Lambda)              (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_9 (Lambda)              (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_10 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_11 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_12 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_13 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_14 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_15 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_16 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_17 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_18 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_19 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_20 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_21 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_22 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_23 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_24 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_25 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  lambda_26 (Lambda)             (None, 15)           0           ['input_variable[0][0]']
#
#  0/0/trend/d1 (Dense)           (None, 256)          4096        ['lambda[0][0]',
#                                                                   'lambda_1[0][0]',
#                                                                   'lambda_2[0][0]',
#                                                                   'lambda_3[0][0]',
#                                                                   'lambda_4[0][0]',
#                                                                   'lambda_5[0][0]',
#                                                                   'lambda_6[0][0]',
#                                                                   'lambda_7[0][0]',
#                                                                   'lambda_8[0][0]',
#                                                                   'lambda_9[0][0]',
#                                                                   'lambda_10[0][0]',
#                                                                   'lambda_11[0][0]',
#                                                                   'lambda_12[0][0]',
#                                                                   'lambda_13[0][0]',
#                                                                   'lambda_14[0][0]',
#                                                                   'lambda_15[0][0]',
#                                                                   'lambda_16[0][0]',
#                                                                   'lambda_17[0][0]',
#                                                                   'lambda_18[0][0]',
#                                                                   'lambda_19[0][0]',
#                                                                   'lambda_20[0][0]',
#                                                                   'lambda_21[0][0]',
#                                                                   'lambda_22[0][0]',
#                                                                   'lambda_23[0][0]',
#                                                                   'lambda_24[0][0]',
#                                                                   'lambda_25[0][0]',
#                                                                   '0/0/trend/d4[21][0]',
#                                                                   '0/0/trend/d4[21][0]',
#                                                                   '0/0/trend/d4[22][0]',
#                                                                   '0/0/trend/d4[22][0]',
#                                                                   '0/0/trend/d4[23][0]',
#                                                                   '0/0/trend/d4[23][0]',
#                                                                   '0/0/trend/d4[24][0]',
#                                                                   '0/0/trend/d4[24][0]',
#                                                                   '0/0/trend/d4[25][0]',
#                                                                   '0/0/trend/d4[25][0]',
#                                                                   '0/0/trend/d4[26][0]',
#                                                                   '0/0/trend/d4[26][0]']
#
#  lambda_27 (Lambda)             (None, 15)           0           ['0/0/trend/theta_f_b[1][0]',
#                                                                   '0/0/trend/theta_f_b[3][0]',
#                                                                   '0/0/trend/theta_f_b[5][0]',
#                                                                   '0/0/trend/theta_f_b[7][0]',
#                                                                   '0/0/trend/theta_f_b[9][0]',
#                                                                   '0/0/trend/theta_f_b[11][0]',
#                                                                   '0/0/trend/theta_f_b[13][0]',
#                                                                   '0/0/trend/theta_f_b[15][0]',
#                                                                   '0/0/trend/theta_f_b[17][0]',
#                                                                   '0/0/trend/theta_f_b[19][0]',
#                                                                   '0/0/trend/theta_f_b[21][0]',
#                                                                   '0/0/trend/theta_f_b[23][0]',
#                                                                   '0/0/trend/theta_f_b[25][0]',
#                                                                   '0/0/trend/theta_f_b[27][0]',
#                                                                   '0/0/trend/theta_f_b[29][0]',
#                                                                   '0/0/trend/theta_f_b[31][0]',
#                                                                   '0/0/trend/theta_f_b[33][0]',
#                                                                   '0/0/trend/theta_f_b[35][0]',
#                                                                   '0/0/trend/theta_f_b[37][0]',
#                                                                   '0/0/trend/theta_f_b[39][0]',
#                                                                   '0/0/trend/theta_f_b[41][0]',
#                                                                   '0/0/trend/theta_f_b[43][0]',
#                                                                   '0/0/trend/theta_f_b[45][0]',
#                                                                   '0/0/trend/theta_f_b[47][0]',
#                                                                   '0/0/trend/theta_f_b[49][0]',
#                                                                   '0/0/trend/theta_f_b[51][0]',
#                                                                   '0/0/trend/theta_f_b[53][0]']
#
#  subtract (Subtract)            (None, 15)           0           ['lambda[0][0]',
#                                                                   'lambda_27[0][0]']
#
#  subtract_1 (Subtract)          (None, 15)           0           ['lambda_1[0][0]',
#                                                                   'lambda_27[1][0]']
#
#  subtract_2 (Subtract)          (None, 15)           0           ['lambda_2[0][0]',
#                                                                   'lambda_27[2][0]']
#
#  subtract_3 (Subtract)          (None, 15)           0           ['lambda_3[0][0]',
#                                                                   'lambda_27[3][0]']
#
#  subtract_4 (Subtract)          (None, 15)           0           ['lambda_4[0][0]',
#                                                                   'lambda_27[4][0]']
#
#  subtract_5 (Subtract)          (None, 15)           0           ['lambda_5[0][0]',
#                                                                   'lambda_27[5][0]']
#
#  subtract_6 (Subtract)          (None, 15)           0           ['lambda_6[0][0]',
#                                                                   'lambda_27[6][0]']
#
#  subtract_7 (Subtract)          (None, 15)           0           ['lambda_7[0][0]',
#                                                                   'lambda_27[7][0]']
#
#  subtract_8 (Subtract)          (None, 15)           0           ['lambda_8[0][0]',
#                                                                   'lambda_27[8][0]']
#
#  subtract_9 (Subtract)          (None, 15)           0           ['lambda_9[0][0]',
#                                                                   'lambda_27[9][0]']
#
#  subtract_10 (Subtract)         (None, 15)           0           ['lambda_10[0][0]',
#                                                                   'lambda_27[10][0]']
#
#  subtract_11 (Subtract)         (None, 15)           0           ['lambda_11[0][0]',
#                                                                   'lambda_27[11][0]']
#
#  subtract_12 (Subtract)         (None, 15)           0           ['lambda_12[0][0]',
#                                                                   'lambda_27[12][0]']
#
#  subtract_13 (Subtract)         (None, 15)           0           ['lambda_13[0][0]',
#                                                                   'lambda_27[13][0]']
#
#  subtract_14 (Subtract)         (None, 15)           0           ['lambda_14[0][0]',
#                                                                   'lambda_27[14][0]']
#
#  subtract_15 (Subtract)         (None, 15)           0           ['lambda_15[0][0]',
#                                                                   'lambda_27[15][0]']
#
#  subtract_16 (Subtract)         (None, 15)           0           ['lambda_16[0][0]',
#                                                                   'lambda_27[16][0]']
#
#  subtract_17 (Subtract)         (None, 15)           0           ['lambda_17[0][0]',
#                                                                   'lambda_27[17][0]']
#
#  subtract_18 (Subtract)         (None, 15)           0           ['lambda_18[0][0]',
#                                                                   'lambda_27[18][0]']
#
#  subtract_19 (Subtract)         (None, 15)           0           ['lambda_19[0][0]',
#                                                                   'lambda_27[19][0]']
#
#  subtract_20 (Subtract)         (None, 15)           0           ['lambda_20[0][0]',
#                                                                   'lambda_27[20][0]']
#
#  subtract_21 (Subtract)         (None, 15)           0           ['lambda_21[0][0]',
#                                                                   'lambda_27[21][0]']
#
#  subtract_22 (Subtract)         (None, 15)           0           ['lambda_22[0][0]',
#                                                                   'lambda_27[22][0]']
#
#  subtract_23 (Subtract)         (None, 15)           0           ['lambda_23[0][0]',
#                                                                   'lambda_27[23][0]']
#
#  subtract_24 (Subtract)         (None, 15)           0           ['lambda_24[0][0]',
#                                                                   'lambda_27[24][0]']
#
#  subtract_25 (Subtract)         (None, 15)           0           ['lambda_25[0][0]',
#                                                                   'lambda_27[25][0]']
#
#  subtract_26 (Subtract)         (None, 15)           0           ['lambda_26[0][0]',
#                                                                   'lambda_27[26][0]']
#
#  0/1/trend/d1 (Dense)           (None, 256)          4096        ['subtract[0][0]',
#                                                                   'subtract_1[0][0]',
#                                                                   'subtract_2[0][0]',
#                                                                   'subtract_3[0][0]',
#                                                                   'subtract_4[0][0]',
#                                                                   'subtract_5[0][0]',
#                                                                   'subtract_6[0][0]',
#                                                                   'subtract_7[0][0]',
#                                                                   'subtract_8[0][0]',
#                                                                   'subtract_9[0][0]',
#                                                                   'subtract_10[0][0]',
#                                                                   'subtract_11[0][0]',
#                                                                   'subtract_12[0][0]',
#                                                                   'subtract_13[0][0]',
#                                                                   'subtract_14[0][0]',
#                                                                   'subtract_15[0][0]',
0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  9[0][0]']
#
#  add_118 (Add)                  (None, 15)           0           ['add_91[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  10[0][0]']
#
#  add_119 (Add)                  (None, 15)           0           ['add_92[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  11[0][0]']
#
#  add_120 (Add)                  (None, 15)           0           ['add_93[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  12[0][0]']
#
#  add_121 (Add)                  (None, 15)           0           ['add_94[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  13[0][0]']
#
#  add_122 (Add)                  (None, 15)           0           ['add_95[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  14[0][0]']
#
#  add_123 (Add)                  (None, 15)           0           ['add_96[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  15[0][0]']
#
#  add_124 (Add)                  (None, 15)           0           ['add_97[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  16[0][0]']
#
#  add_125 (Add)                  (None, 15)           0           ['add_98[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  17[0][0]']
#
#  add_126 (Add)                  (None, 15)           0           ['add_99[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  18[0][0]']
#
#  add_127 (Add)                  (None, 15)           0           ['add_100[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  19[0][0]']
#
#  add_128 (Add)                  (None, 15)           0           ['add_101[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  20[0][0]']
#
#  add_129 (Add)                  (None, 15)           0           ['add_102[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  21[0][0]']
#
#  add_130 (Add)                  (None, 15)           0           ['add_103[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  22[0][0]']
#
#  add_131 (Add)                  (None, 15)           0           ['add_104[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  23[0][0]']
#
#  add_132 (Add)                  (None, 15)           0           ['add_105[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  24[0][0]']
#
#  add_133 (Add)                  (None, 15)           0           ['add_106[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  25[0][0]']
#
#  add_134 (Add)                  (None, 15)           0           ['add_107[0][0]',
#                                                                   'stack_1-SeasonalityBlock_2_Dim_
#                                                                  26[0][0]']
#
#  reshape (Reshape)              (None, 15, 1)        0           ['add_108[0][0]']
#
#  reshape_2 (Reshape)            (None, 15, 1)        0           ['add_109[0][0]']
#
#  reshape_4 (Reshape)            (None, 15, 1)        0           ['add_110[0][0]']
#
#  reshape_6 (Reshape)            (None, 15, 1)        0           ['add_111[0][0]']
#
#  reshape_8 (Reshape)            (None, 15, 1)        0           ['add_112[0][0]']
#
#  reshape_10 (Reshape)           (None, 15, 1)        0           ['add_113[0][0]']
#
#  reshape_12 (Reshape)           (None, 15, 1)        0           ['add_114[0][0]']
#
#  reshape_14 (Reshape)           (None, 15, 1)        0           ['add_115[0][0]']
#
#  reshape_16 (Reshape)           (None, 15, 1)        0           ['add_116[0][0]']
#
#  reshape_18 (Reshape)           (None, 15, 1)        0           ['add_117[0][0]']
#
#  reshape_20 (Reshape)           (None, 15, 1)        0           ['add_118[0][0]']
#
#  reshape_22 (Reshape)           (None, 15, 1)        0           ['add_119[0][0]']
#
#  reshape_24 (Reshape)           (None, 15, 1)        0           ['add_120[0][0]']
#
#  reshape_26 (Reshape)           (None, 15, 1)        0           ['add_121[0][0]']
#
#  reshape_28 (Reshape)           (None, 15, 1)        0           ['add_122[0][0]']
#
#  reshape_30 (Reshape)           (None, 15, 1)        0           ['add_123[0][0]']
#
#  reshape_32 (Reshape)           (None, 15, 1)        0           ['add_124[0][0]']
#
#  reshape_34 (Reshape)           (None, 15, 1)        0           ['add_125[0][0]']
#
#  reshape_36 (Reshape)           (None, 15, 1)        0           ['add_126[0][0]']
#
#  reshape_38 (Reshape)           (None, 15, 1)        0           ['add_127[0][0]']
#
#  reshape_40 (Reshape)           (None, 15, 1)        0           ['add_128[0][0]']
#
#  reshape_42 (Reshape)           (None, 15, 1)        0           ['add_129[0][0]']
#
#  reshape_44 (Reshape)           (None, 15, 1)        0           ['add_130[0][0]']
#
#  reshape_46 (Reshape)           (None, 15, 1)        0           ['add_131[0][0]']
#
#  reshape_48 (Reshape)           (None, 15, 1)        0           ['add_132[0][0]']
#
#  reshape_50 (Reshape)           (None, 15, 1)        0           ['add_133[0][0]']
#
#  reshape_52 (Reshape)           (None, 15, 1)        0           ['add_134[0][0]']
#
#  concatenate (Concatenate)      (None, 15, 27)       0           ['reshape[0][0]',
#                                                                   'reshape_2[0][0]',
#                                                                   'reshape_4[0][0]',
#                                                                   'reshape_6[0][0]',
#                                                                   'reshape_8[0][0]',
#                                                                   'reshape_10[0][0]',
#                                                                   'reshape_12[0][0]',
#                                                                   'reshape_14[0][0]',
#                                                                   'reshape_16[0][0]',
#                                                                   'reshape_18[0][0]',
#                                                                   'reshape_20[0][0]',
#                                                                   'reshape_22[0][0]',
#                                                                   'reshape_24[0][0]',
#                                                                   'reshape_26[0][0]',
#                                                                   'reshape_28[0][0]',
#                                                                   'reshape_30[0][0]',
#                                                                   'reshape_32[0][0]',
#                                                                   'reshape_34[0][0]',
#                                                                   'reshape_36[0][0]',
#                                                                   'reshape_38[0][0]',
#                                                                   'reshape_40[0][0]',
#                                                                   'reshape_42[0][0]',
#                                                                   'reshape_44[0][0]',
#                                                                   'reshape_46[0][0]',
#                                                                   'reshape_48[0][0]',
#                                                                   'reshape_50[0][0]',
#                                                                   'reshape_52[0][0]']
#
#  flatten (Flatten)              (None, 405)          0           ['concatenate[0][0]']
#
#  reg_y (Dense)                  (None, 15)           6090        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 1,237,194
# Trainable params: 1,237,194
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss ='mae')
history = model.fit(X_train , Y_train, epochs=100, batch_size=16, verbose= 1,validation_split=0.2,callbacks=callback)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 81s 7s/step - loss: 0.1844 - val_loss: 0.2188
# Epoch 2/100
# 4/4 [==============================] - 1s 199ms/step - loss: 0.1446 - val_loss: 0.2074
# Epoch 3/100
# 4/4 [==============================] - 1s 211ms/step - loss: 0.1296 - val_loss: 0.2149
# Epoch 4/100
# 4/4 [==============================] - 1s 206ms/step - loss: 0.1261 - val_loss: 0.2085
# Epoch 5/100
# 4/4 [==============================] - 1s 202ms/step - loss: 0.1179 - val_loss: 0.2170
# Epoch 6/100
# 4/4 [==============================] - 1s 193ms/step - loss: 0.1127 - val_loss: 0.2130
# Epoch 7/100
# 4/4 [==============================] - 1s 192ms/step - loss: 0.1076 - val_loss: 0.2189
# Epoch 8/100
# 4/4 [==============================] - 1s 198ms/step - loss: 0.1038 - val_loss: 0.2114
# Epoch 9/100
# 4/4 [==============================] - 1s 181ms/step - loss: 0.1027 - val_loss: 0.2161
# Epoch 10/100
# 4/4 [==============================] - 1s 193ms/step - loss: 0.0990 - val_loss: 0.2149
# Epoch 11/100
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0971 - val_loss: 0.2137
# Epoch 12/100
# 4/4 [==============================] - 1s 210ms/step - loss: 0.0967 - val_loss: 0.2154
# Epoch 13/100
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0936 - val_loss: 0.2206
# Epoch 14/100
# 4/4 [==============================] - 1s 185ms/step - loss: 0.0935 - val_loss: 0.2143
# Epoch 15/100
# 4/4 [==============================] - 1s 187ms/step - loss: 0.0893 - val_loss: 0.2231
# Epoch 16/100
# 4/4 [==============================] - 1s 184ms/step - loss: 0.0875 - val_loss: 0.2181
# Epoch 17/100
# 4/4 [==============================] - 1s 187ms/step - loss: 0.0882 - val_loss: 0.2191
# Epoch 18/100
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0847 - val_loss: 0.2234
# Epoch 19/100
# 4/4 [==============================] - 1s 207ms/step - loss: 0.0792 - val_loss: 0.2232
# Epoch 20/100
# 4/4 [==============================] - 1s 206ms/step - loss: 0.0762 - val_loss: 0.2255
# Epoch 21/100
# 4/4 [==============================] - 1s 193ms/step - loss: 0.0738 - val_loss: 0.2215
# Epoch 22/100
# 4/4 [==============================] - 1s 197ms/step - loss: 0.0707 - val_loss: 0.2278
# Epoch 23/100
# 4/4 [==============================] - 1s 186ms/step - loss: 0.0681 - val_loss: 0.2233
# Epoch 24/100
# 4/4 [==============================] - 1s 173ms/step - loss: 0.0620 - val_loss: 0.2231
# Epoch 25/100
# 4/4 [==============================] - 1s 183ms/step - loss: 0.0593 - val_loss: 0.2285
# Epoch 26/100
# 4/4 [==============================] - 1s 185ms/step - loss: 0.0630 - val_loss: 0.2237
# Epoch 27/100
# 4/4 [==============================] - 1s 207ms/step - loss: 0.0578 - val_loss: 0.2243
# Epoch 28/100
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0572 - val_loss: 0.2317
# Epoch 29/100
# 4/4 [==============================] - 1s 183ms/step - loss: 0.0549 - val_loss: 0.2299
# Epoch 30/100
# 4/4 [==============================] - 1s 174ms/step - loss: 0.0519 - val_loss: 0.2300
# Epoch 31/100
# 4/4 [==============================] - 1s 180ms/step - loss: 0.0553 - val_loss: 0.2262
# Epoch 32/100
# 4/4 [==============================] - 1s 177ms/step - loss: 0.0532 - val_loss: 0.2244
# Epoch 33/100
# 4/4 [==============================] - 1s 174ms/step - loss: 0.0550 - val_loss: 0.2263
# Epoch 34/100
# 4/4 [==============================] - 1s 181ms/step - loss: 0.0509 - val_loss: 0.2248
# Epoch 35/100
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0476 - val_loss: 0.2261
# Epoch 36/100
# 4/4 [==============================] - 1s 193ms/step - loss: 0.0488 - val_loss: 0.2247
# Epoch 37/100
# 4/4 [==============================] - 1s 184ms/step - loss: 0.0476 - val_loss: 0.2302
# Epoch 38/100
# 4/4 [==============================] - 1s 175ms/step - loss: 0.0486 - val_loss: 0.2260
# Epoch 39/100
# 4/4 [==============================] - 1s 172ms/step - loss: 0.0446 - val_loss: 0.2275
# Epoch 40/100
# 4/4 [==============================] - 1s 177ms/step - loss: 0.0467 - val_loss: 0.2277
# Epoch 41/100
# 4/4 [==============================] - 1s 173ms/step - loss: 0.0452 - val_loss: 0.2226
# Epoch 42/100
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0433 - val_loss: 0.2226
# Epoch 43/100
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0417 - val_loss: 0.2242
# Epoch 44/100
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0393 - val_loss: 0.2264
# Epoch 45/100
# 4/4 [==============================] - 1s 175ms/step - loss: 0.0440 - val_loss: 0.2250
# Epoch 46/100
# 4/4 [==============================] - 1s 172ms/step - loss: 0.0393 - val_loss: 0.2305
# Epoch 47/100
# 4/4 [==============================] - 1s 165ms/step - loss: 0.0378 - val_loss: 0.2265
# Epoch 48/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.0389 - val_loss: 0.2253
# Epoch 49/100
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0409 - val_loss: 0.2258
# Epoch 50/100
# 4/4 [==============================] - 1s 201ms/step - loss: 0.0399 - val_loss: 0.2250
# Epoch 51/100
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0425 - val_loss: 0.2258
# Epoch 52/100
# 4/4 [==============================] - 1s 177ms/step - loss: 0.0418 - val_loss: 0.2268
# Epoch 53/100
# 4/4 [==============================] - 1s 174ms/step - loss: 0.0428 - val_loss: 0.2243
# Epoch 54/100
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0428 - val_loss: 0.2249
# Epoch 55/100
# 4/4 [==============================] - 1s 168ms/step - loss: 0.0387 - val_loss: 0.2218
# Epoch 56/100
# 4/4 [==============================] - 1s 182ms/step - loss: 0.0378 - val_loss: 0.2224
# Epoch 57/100
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0384 - val_loss: 0.2212
# Epoch 58/100
# 4/4 [==============================] - 1s 206ms/step - loss: 0.0374 - val_loss: 0.2186
# Epoch 59/100
# 4/4 [==============================] - 1s 191ms/step - loss: 0.0368 - val_loss: 0.2197
# Epoch 60/100
# 4/4 [==============================] - 1s 186ms/step - loss: 0.0363 - val_loss: 0.2246
# Epoch 61/100
# 4/4 [==============================] - 1s 175ms/step - loss: 0.0350 - val_loss: 0.2184
# Epoch 62/100
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0350 - val_loss: 0.2206
# Epoch 63/100
# 4/4 [==============================] - 1s 178ms/step - loss: 0.0329 - val_loss: 0.2188
# Epoch 64/100
# 4/4 [==============================] - 1s 190ms/step - loss: 0.0339 - val_loss: 0.2224
# Epoch 65/100
# 4/4 [==============================] - 1s 219ms/step - loss: 0.0345 - val_loss: 0.2220
# Epoch 66/100
# 4/4 [==============================] - 1s 221ms/step - loss: 0.0333 - val_loss: 0.2213
# Epoch 67/100
# 4/4 [==============================] - 1s 208ms/step - loss: 0.0342 - val_loss: 0.2207
# Epoch 68/100
# 4/4 [==============================] - 1s 240ms/step - loss: 0.0332 - val_loss: 0.2211
# Epoch 69/100
# 4/4 [==============================] - 1s 211ms/step - loss: 0.0334 - val_loss: 0.2241
# Epoch 70/100
# 4/4 [==============================] - 1s 176ms/step - loss: 0.0319 - val_loss: 0.2204
# Epoch 71/100
# 4/4 [==============================] - 1s 196ms/step - loss: 0.0321 - val_loss: 0.2217
# Epoch 72/100
# 4/4 [==============================] - 1s 209ms/step - loss: 0.0335 - val_loss: 0.2224
# Epoch 73/100
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0321 - val_loss: 0.2217
# Epoch 74/100
# 4/4 [==============================] - 1s 206ms/step - loss: 0.0308 - val_loss: 0.2223
# Epoch 75/100
# 4/4 [==============================] - 1s 189ms/step - loss: 0.0304 - val_loss: 0.2208
# Epoch 76/100
# 4/4 [==============================] - 1s 184ms/step - loss: 0.0311 - val_loss: 0.2189
# Epoch 77/100
# 4/4 [==============================] - 1s 185ms/step - loss: 0.0312 - val_loss: 0.2194
# Epoch 78/100
# 4/4 [==============================] - 1s 181ms/step - loss: 0.0308 - val_loss: 0.2193
# Epoch 79/100
# 4/4 [==============================] - 1s 179ms/step - loss: 0.0307 - val_loss: 0.2191
# Epoch 80/100
# 4/4 [==============================] - 1s 204ms/step - loss: 0.0302 - val_loss: 0.2217
# Epoch 81/100
# 4/4 [==============================] - 1s 203ms/step - loss: 0.0286 - val_loss: 0.2207
# Epoch 82/100
# 4/4 [==============================] - 1s 187ms/step - loss: 0.0274 - val_loss: 0.2212
# Epoch 83/100
# 4/4 [==============================] - 1s 172ms/step - loss: 0.0284 - val_loss: 0.2185
# Epoch 84/100
# 4/4 [==============================] - 1s 149ms/step - loss: 0.0288 - val_loss: 0.2231
# Epoch 85/100
# 4/4 [==============================] - 1s 168ms/step - loss: 0.0297 - val_loss: 0.2200
# Epoch 86/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.0295 - val_loss: 0.2191
# Epoch 87/100
# 4/4 [==============================] - 1s 146ms/step - loss: 0.0289 - val_loss: 0.2213
# Epoch 88/100
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0279 - val_loss: 0.2201
# Epoch 89/100
# 4/4 [==============================] - 1s 198ms/step - loss: 0.0280 - val_loss: 0.2231
# Epoch 90/100
# 4/4 [==============================] - 1s 195ms/step - loss: 0.0288 - val_loss: 0.2210
# Epoch 91/100
# 4/4 [==============================] - 1s 172ms/step - loss: 0.0273 - val_loss: 0.2193
# Epoch 92/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.0262 - val_loss: 0.2201
# Epoch 93/100
# 4/4 [==============================] - 1s 164ms/step - loss: 0.0262 - val_loss: 0.2183
# Epoch 94/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.0252 - val_loss: 0.2190
# Epoch 95/100
# 4/4 [==============================] - 1s 202ms/step - loss: 0.0266 - val_loss: 0.2197
# Epoch 96/100
# 4/4 [==============================] - 1s 218ms/step - loss: 0.0266 - val_loss: 0.2187
# Epoch 97/100
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0263 - val_loss: 0.2201
# Epoch 98/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.0285 - val_loss: 0.2192
# Epoch 99/100
# 4/4 [==============================] - 1s 157ms/step - loss: 0.0267 - val_loss: 0.2200
# Epoch 100/100
# 4/4 [==============================] - 1s 169ms/step - loss: 0.0242 - val_loss: 0.2209

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error, mean_absolute_percentage_error
def root_mean_squared_error(y_true, y_pred):    
    return np.sqrt(mean_squared_error(y_true, y_pred))
def root_mean_squared_log_error(real, predicted):
    sum=0.0
    for x in range(len(predicted)):
        if predicted[x]<0 or real[x]<0: # check for negative values
            continue
        p = np.log(predicted[x]+1)
        r = np.log(real[x]+1)
        sum = sum + (p - r)**2
    return (sum/len(predicted))**0.5
def print_metrics():
    print('Train   RMSE  value   : %.3f ' % root_mean_squared_error(Y_train, model.predict(X_train)))
    print('Train   MSE   value   : %.3f ' % mean_squared_error(Y_train, model.predict(X_train)))
    print('Train   R2    value   : %.3f ' % r2_score(Y_train,model.predict(X_train)))
    print('Train   MAPE  value   : %.3f ' % mean_absolute_percentage_error(Y_train, model.predict(X_train)))
    print('Train   MAE   value   : %.3f ' % mean_absolute_error(Y_train, model.predict(X_train)))
    print('---------------------------------------------')
    print('Test    RMSE  value   : %.3f ' % root_mean_squared_error(Y_test, model.predict(X_test)))
    print('Test    MSE   value   : %.3f ' % mean_squared_error(Y_test, model.predict(X_test)))
    print('Test    R2    value   : %.3f ' % r2_score(Y_test, model.predict(X_test)))
    print('Test    MAPE  value   : %.3f ' % mean_absolute_percentage_error(Y_test, model.predict(X_test)))
    print('Test    MAE   value   : %.3f ' % mean_absolute_error(Y_test, model.predict(X_test)))

# %%
print_metrics()
# Out:
# 3/3 [==============================] - 144s 58ms/step
# Train   RMSE  value   : 0.136
# 3/3 [==============================] - 0s 50ms/step
# Train   MSE   value   : 0.018
# 3/3 [==============================] - 0s 58ms/step
# Train   R2    value   : 0.526
# 3/3 [==============================] - 0s 50ms/step
# Train   MAPE  value   : 460565303536.195
# 3/3 [==============================] - 0s 50ms/step
# Train   MAE   value   : 0.065
# ---------------------------------------------
# 1/1 [==============================] - 0s 62ms/step
# Test    RMSE  value   : 0.186
# 1/1 [==============================] - 0s 85ms/step
# Test    MSE   value   : 0.034
# 1/1 [==============================] - 0s 85ms/step
# Test    R2    value   : 0.060
# 1/1 [==============================] - 0s 69ms/step
# Test    MAPE  value   : 0.465
# 1/1 [==============================] - 0s 78ms/step
# Test    MAE   value   : 0.146

# %%
# Plot of loss vs epoch for train and test dataset
from matplotlib import pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

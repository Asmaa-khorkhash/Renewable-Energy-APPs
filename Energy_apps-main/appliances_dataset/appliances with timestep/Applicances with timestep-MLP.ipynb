# %%
import numpy as np 
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input,Dense, Activation, Dropout,Flatten
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('C:\\Users\\M4\\Desktop\\KAG_energydata_complete.csv',parse_dates=['date'], index_col= 'date')

# %%
df
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:00:00          60      30  19.890000  47.596667  19.200000
# 2016-01-11 17:10:00          60      30  19.890000  46.693333  19.200000
# 2016-01-11 17:20:00          50      30  19.890000  46.300000  19.200000
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 2016-01-11 17:40:00          60      40  19.890000  46.333333  19.200000
# ...                         ...     ...        ...        ...        ...
# 2016-05-27 17:20:00         100       0  25.566667  46.560000  25.890000
# 2016-05-27 17:30:00          90       0  25.500000  46.500000  25.754000
# 2016-05-27 17:40:00         270      10  25.500000  46.596667  25.628571
# 2016-05-27 17:50:00         420      10  25.500000  46.990000  25.414000
# 2016-05-27 18:00:00         430      10  25.500000  46.600000  25.264286
#
#                           RH_2         T3       RH_3         T4       RH_4  \
# date
# 2016-01-11 17:00:00  44.790000  19.790000  44.730000  19.000000  45.566667
# 2016-01-11 17:10:00  44.722500  19.790000  44.790000  19.000000  45.992500
# 2016-01-11 17:20:00  44.626667  19.790000  44.933333  18.926667  45.890000
# 2016-01-11 17:30:00  44.590000  19.790000  45.000000  18.890000  45.723333
# 2016-01-11 17:40:00  44.530000  19.790000  45.000000  18.890000  45.530000
# ...                        ...        ...        ...        ...        ...
# 2016-05-27 17:20:00  42.025714  27.200000  41.163333  24.700000  45.590000
# 2016-05-27 17:30:00  42.080000  27.133333  41.223333  24.700000  45.590000
# 2016-05-27 17:40:00  42.768571  27.050000  41.690000  24.700000  45.730000
# 2016-05-27 17:50:00  43.036000  26.890000  41.290000  24.700000  45.790000
# 2016-05-27 18:00:00  42.971429  26.823333  41.156667  24.700000  45.963333
#
#                      ...         T9     RH_9      T_out  Press_mm_hg  \
# date                 ...
# 2016-01-11 17:00:00  ...  17.033333  45.5300   6.600000        733.5
# 2016-01-11 17:10:00  ...  17.066667  45.5600   6.483333        733.6
# 2016-01-11 17:20:00  ...  17.000000  45.5000   6.366667        733.7
# 2016-01-11 17:30:00  ...  17.000000  45.4000   6.250000        733.8
# 2016-01-11 17:40:00  ...  17.000000  45.4000   6.133333        733.9
# ...                  ...        ...      ...        ...          ...
# 2016-05-27 17:20:00  ...  23.200000  46.7900  22.733333        755.2
# 2016-05-27 17:30:00  ...  23.200000  46.7900  22.600000        755.2
# 2016-05-27 17:40:00  ...  23.200000  46.7900  22.466667        755.2
# 2016-05-27 17:50:00  ...  23.200000  46.8175  22.333333        755.2
# 2016-05-27 18:00:00  ...  23.200000  46.8450  22.200000        755.2
#
#                         RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# date
# 2016-01-11 17:00:00  92.000000   7.000000   63.000000   5.300000  13.275433
# 2016-01-11 17:10:00  92.000000   6.666667   59.166667   5.200000  18.606195
# 2016-01-11 17:20:00  92.000000   6.333333   55.333333   5.100000  28.642668
# 2016-01-11 17:30:00  92.000000   6.000000   51.500000   5.000000  45.410389
# 2016-01-11 17:40:00  92.000000   5.666667   47.666667   4.900000  10.084097
# ...                        ...        ...         ...        ...        ...
# 2016-05-27 17:20:00  55.666667   3.333333   23.666667  13.333333  43.096812
# 2016-05-27 17:30:00  56.000000   3.500000   24.500000  13.300000  49.282940
# 2016-05-27 17:40:00  56.333333   3.666667   25.333333  13.266667  29.199117
# 2016-05-27 17:50:00  56.666667   3.833333   26.166667  13.233333   6.322784
# 2016-05-27 18:00:00  57.000000   4.000000   27.000000  13.200000  34.118851
#
#                            rv2
# date
# 2016-01-11 17:00:00  13.275433
# 2016-01-11 17:10:00  18.606195
# 2016-01-11 17:20:00  28.642668
# 2016-01-11 17:30:00  45.410389
# 2016-01-11 17:40:00  10.084097
# ...                        ...
# 2016-05-27 17:20:00  43.096812
# 2016-05-27 17:30:00  49.282940
# 2016-05-27 17:40:00  29.199117
# 2016-05-27 17:50:00   6.322784
# 2016-05-27 18:00:00  34.118851
#
# [19735 rows x 28 columns]

# %%
data = df.resample('D').sum()

# %%
df = df.resample('D').mean()
df.shape
# Out:
# (138, 28)

# %%
def train_test_split(df):
    
    # compute split point
    end_idx = df.shape[0]* 70 // 100
    
    train_data = df.iloc[1:end_idx, : ]
    test_data = df.iloc[end_idx:, :]
    
    return train_data, test_data

# Split the data into train and test
X_train, X_test = train_test_split(df)

# %%
X_test.shape , X_train.shape
# Out:
# ((42, 28), (95, 28))

# %%
from sklearn.preprocessing import MinMaxScaler
def scale_data(train, test):
    scaler = MinMaxScaler().fit(train)
    return scaler.transform(train), scaler.transform(test), scaler

# %%
X_train, X_test, scaler = scale_data(X_train, X_test)

# %%
def multivariate_splitter(df):

    input_features = []
    ouput_feature = []
    
    len_df = df.shape[0]
    
    for i in range(len_df):
        
        end_idx = i + 15
        
        if end_idx > len_df-15:
            break
            
        input_x , output_y = df[i:end_idx, 1:], df[end_idx: end_idx+15, 0]
        
        input_features.append(input_x)
        ouput_feature.append(output_y)
    
    return np.array(input_features), np.array(ouput_feature)

# %%
X_train, Y_train = multivariate_splitter(X_train)
X_test, Y_test = multivariate_splitter(X_test)

# %%
print('Shape of (training data) input features : %s and ouput feature %s' % (X_train.shape, Y_train.shape))
print('Shape of (testing data) input features : %s and ouput feature %s' % (X_test.shape, Y_test.shape))
# Out:
# Shape of (training data) input features : (66, 15, 27) and ouput feature (66, 15)
# Shape of (testing data) input features : (13, 15, 27) and ouput feature (13, 15)

# %%
import tensorflow as tf
from Energy_Models.MLP import MLP
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model = MLP(15,27,15).getModel()

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 15, 27)]          0
#
#  mlp_1 (MLP)                 (None, 15)                11087
#
# =================================================================
# Total params: 11,087
# Trainable params: 11,087
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss ='mae')
history = model.fit(X_train , Y_train, epochs=100, batch_size=16, verbose= 1,validation_split=0.2,callbacks=callback)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 83ms/step - loss: 0.5019 - val_loss: 0.3279
# Epoch 2/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3493 - val_loss: 0.2290
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2826 - val_loss: 0.1990
# Epoch 4/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2517 - val_loss: 0.1989
# Epoch 5/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2375 - val_loss: 0.2103
# Epoch 6/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2238 - val_loss: 0.2174
# Epoch 7/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2132 - val_loss: 0.2192
# Epoch 8/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2059 - val_loss: 0.2144
# Epoch 9/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1977 - val_loss: 0.2011
# Epoch 10/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1886 - val_loss: 0.1965
# Epoch 11/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1838 - val_loss: 0.1968
# Epoch 12/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1788 - val_loss: 0.1955
# Epoch 13/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1708 - val_loss: 0.1949
# Epoch 14/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1671 - val_loss: 0.1936
# Epoch 15/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1655 - val_loss: 0.1931
# Epoch 16/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1715 - val_loss: 0.1930
# Epoch 17/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1689 - val_loss: 0.1944
# Epoch 18/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1630 - val_loss: 0.1956
# Epoch 19/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1591 - val_loss: 0.1919
# Epoch 20/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1543 - val_loss: 0.1914
# Epoch 21/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1587 - val_loss: 0.1920
# Epoch 22/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1547 - val_loss: 0.1936
# Epoch 23/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1534 - val_loss: 0.1928
# Epoch 24/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1508 - val_loss: 0.1958
# Epoch 25/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1567 - val_loss: 0.1950
# Epoch 26/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1477 - val_loss: 0.1939
# Epoch 27/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1530 - val_loss: 0.1932
# Epoch 28/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1475 - val_loss: 0.1959
# Epoch 29/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1506 - val_loss: 0.1927
# Epoch 30/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1472 - val_loss: 0.1924
# Epoch 31/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1455 - val_loss: 0.1921
# Epoch 32/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1441 - val_loss: 0.1929
# Epoch 33/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1444 - val_loss: 0.1918
# Epoch 34/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1449 - val_loss: 0.1923
# Epoch 35/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1419 - val_loss: 0.1955
# Epoch 36/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1453 - val_loss: 0.1939
# Epoch 37/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1414 - val_loss: 0.1925
# Epoch 38/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1352 - val_loss: 0.1923
# Epoch 39/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1413 - val_loss: 0.1936
# Epoch 40/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1388 - val_loss: 0.1923
# Epoch 41/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1392 - val_loss: 0.1931
# Epoch 42/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1385 - val_loss: 0.1958
# Epoch 43/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1389 - val_loss: 0.1945
# Epoch 44/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1367 - val_loss: 0.1920
# Epoch 45/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1360 - val_loss: 0.1923
# Epoch 46/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1324 - val_loss: 0.1926
# Epoch 47/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1327 - val_loss: 0.1921
# Epoch 48/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1305 - val_loss: 0.1921
# Epoch 49/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1331 - val_loss: 0.1905
# Epoch 50/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1285 - val_loss: 0.1950
# Epoch 51/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1367 - val_loss: 0.2019
# Epoch 52/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1336 - val_loss: 0.1944
# Epoch 53/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1287 - val_loss: 0.1955
# Epoch 54/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1315 - val_loss: 0.2013
# Epoch 55/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1300 - val_loss: 0.1970
# Epoch 56/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1258 - val_loss: 0.1910
# Epoch 57/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1260 - val_loss: 0.1913
# Epoch 58/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1274 - val_loss: 0.1935
# Epoch 59/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1249 - val_loss: 0.1936
# Epoch 60/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1221 - val_loss: 0.1933
# Epoch 61/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1252 - val_loss: 0.1911
# Epoch 62/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1223 - val_loss: 0.1926
# Epoch 63/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1227 - val_loss: 0.1938
# Epoch 64/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1206 - val_loss: 0.1922
# Epoch 65/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1207 - val_loss: 0.1924
# Epoch 66/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1222 - val_loss: 0.1935
# Epoch 67/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1187 - val_loss: 0.1924
# Epoch 68/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1195 - val_loss: 0.1922
# Epoch 69/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1139 - val_loss: 0.1941
# Epoch 70/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1165 - val_loss: 0.1929
# Epoch 71/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1137 - val_loss: 0.1930
# Epoch 72/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1166 - val_loss: 0.1954
# Epoch 73/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1120 - val_loss: 0.1947
# Epoch 74/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1118 - val_loss: 0.1934
# Epoch 75/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1120 - val_loss: 0.1948
# Epoch 76/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1121 - val_loss: 0.1937
# Epoch 77/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1143 - val_loss: 0.1943
# Epoch 78/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1083 - val_loss: 0.1944
# Epoch 79/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1090 - val_loss: 0.1927
# Epoch 80/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1067 - val_loss: 0.1941
# Epoch 81/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1042 - val_loss: 0.1950
# Epoch 82/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1062 - val_loss: 0.1961
# Epoch 83/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1047 - val_loss: 0.1969
# Epoch 84/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1037 - val_loss: 0.1937
# Epoch 85/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1051 - val_loss: 0.1940
# Epoch 86/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1032 - val_loss: 0.1937
# Epoch 87/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0985 - val_loss: 0.1934
# Epoch 88/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1024 - val_loss: 0.1940
# Epoch 89/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1030 - val_loss: 0.1982
# Epoch 90/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1004 - val_loss: 0.1945
# Epoch 91/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1002 - val_loss: 0.1943
# Epoch 92/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0967 - val_loss: 0.1941
# Epoch 93/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0979 - val_loss: 0.1909
# Epoch 94/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0962 - val_loss: 0.1908
# Epoch 95/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0942 - val_loss: 0.1930
# Epoch 96/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0934 - val_loss: 0.1921
# Epoch 97/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0941 - val_loss: 0.1899
# Epoch 98/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0926 - val_loss: 0.1901
# Epoch 99/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0904 - val_loss: 0.1908
# Epoch 100/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0888 - val_loss: 0.1915

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error, mean_absolute_percentage_error
def root_mean_squared_error(y_true, y_pred):    
    return np.sqrt(mean_squared_error(y_true, y_pred))
def root_mean_squared_log_error(real, predicted):
    sum=0.0
    for x in range(len(predicted)):
        if predicted[x]<0 or real[x]<0: # check for negative values
            continue
        p = np.log(predicted[x]+1)
        r = np.log(real[x]+1)
        sum = sum + (p - r)**2
    return (sum/len(predicted))**0.5
def print_metrics():
    print('Train   RMSE  value   : %.3f ' % root_mean_squared_error(Y_train, model.predict(X_train)))
    print('Train   MSE   value   : %.3f ' % mean_squared_error(Y_train, model.predict(X_train)))
    print('Train   R2    value   : %.3f ' % r2_score(Y_train,model.predict(X_train)))
    print('Train   MAPE  value   : %.3f ' % mean_absolute_percentage_error(Y_train, model.predict(X_train)))
    print('Train   MAE   value   : %.3f ' % mean_absolute_error(Y_train, model.predict(X_train)))
    print('---------------------------------------------')
    print('Test    RMSE  value   : %.3f ' % root_mean_squared_error(Y_test, model.predict(X_test)))
    print('Test    MSE   value   : %.3f ' % mean_squared_error(Y_test, model.predict(X_test)))
    print('Test    R2    value   : %.3f ' % r2_score(Y_test, model.predict(X_test)))
    print('Test    MAPE  value   : %.3f ' % mean_absolute_percentage_error(Y_test, model.predict(X_test)))
    print('Test    MAE   value   : %.3f ' % mean_absolute_error(Y_test, model.predict(X_test)))

# %%
print_metrics()
# Out:
# 3/3 [==============================] - 0s 2ms/step
# Train   RMSE  value   : 0.164
# 3/3 [==============================] - 0s 2ms/step
# Train   MSE   value   : 0.027
# 3/3 [==============================] - 0s 1ms/step
# Train   R2    value   : 0.312
# 3/3 [==============================] - 0s 1ms/step
# Train   MAPE  value   : 268571063356.263
# 3/3 [==============================] - 0s 2ms/step
# Train   MAE   value   : 0.101
# ---------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# Test    RMSE  value   : 0.211
# 1/1 [==============================] - 0s 20ms/step
# Test    MSE   value   : 0.044
# 1/1 [==============================] - 0s 19ms/step
# Test    R2    value   : -0.217
# 1/1 [==============================] - 0s 24ms/step
# Test    MAPE  value   : 0.431
# 1/1 [==============================] - 0s 19ms/step
# Test    MAE   value   : 0.150

# %%
# Plot of loss vs epoch for train and test dataset
from matplotlib import pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
import numpy as np 
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('C:\\Users\\M4\\Desktop\\KAG_energydata_complete.csv',parse_dates=['date'], index_col= 'date')

# %%
df
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:00:00          60      30  19.890000  47.596667  19.200000
# 2016-01-11 17:10:00          60      30  19.890000  46.693333  19.200000
# 2016-01-11 17:20:00          50      30  19.890000  46.300000  19.200000
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 2016-01-11 17:40:00          60      40  19.890000  46.333333  19.200000
# ...                         ...     ...        ...        ...        ...
# 2016-05-27 17:20:00         100       0  25.566667  46.560000  25.890000
# 2016-05-27 17:30:00          90       0  25.500000  46.500000  25.754000
# 2016-05-27 17:40:00         270      10  25.500000  46.596667  25.628571
# 2016-05-27 17:50:00         420      10  25.500000  46.990000  25.414000
# 2016-05-27 18:00:00         430      10  25.500000  46.600000  25.264286
#
#                           RH_2         T3       RH_3         T4       RH_4  \
# date
# 2016-01-11 17:00:00  44.790000  19.790000  44.730000  19.000000  45.566667
# 2016-01-11 17:10:00  44.722500  19.790000  44.790000  19.000000  45.992500
# 2016-01-11 17:20:00  44.626667  19.790000  44.933333  18.926667  45.890000
# 2016-01-11 17:30:00  44.590000  19.790000  45.000000  18.890000  45.723333
# 2016-01-11 17:40:00  44.530000  19.790000  45.000000  18.890000  45.530000
# ...                        ...        ...        ...        ...        ...
# 2016-05-27 17:20:00  42.025714  27.200000  41.163333  24.700000  45.590000
# 2016-05-27 17:30:00  42.080000  27.133333  41.223333  24.700000  45.590000
# 2016-05-27 17:40:00  42.768571  27.050000  41.690000  24.700000  45.730000
# 2016-05-27 17:50:00  43.036000  26.890000  41.290000  24.700000  45.790000
# 2016-05-27 18:00:00  42.971429  26.823333  41.156667  24.700000  45.963333
#
#                      ...         T9     RH_9      T_out  Press_mm_hg  \
# date                 ...
# 2016-01-11 17:00:00  ...  17.033333  45.5300   6.600000        733.5
# 2016-01-11 17:10:00  ...  17.066667  45.5600   6.483333        733.6
# 2016-01-11 17:20:00  ...  17.000000  45.5000   6.366667        733.7
# 2016-01-11 17:30:00  ...  17.000000  45.4000   6.250000        733.8
# 2016-01-11 17:40:00  ...  17.000000  45.4000   6.133333        733.9
# ...                  ...        ...      ...        ...          ...
# 2016-05-27 17:20:00  ...  23.200000  46.7900  22.733333        755.2
# 2016-05-27 17:30:00  ...  23.200000  46.7900  22.600000        755.2
# 2016-05-27 17:40:00  ...  23.200000  46.7900  22.466667        755.2
# 2016-05-27 17:50:00  ...  23.200000  46.8175  22.333333        755.2
# 2016-05-27 18:00:00  ...  23.200000  46.8450  22.200000        755.2
#
#                         RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# date
# 2016-01-11 17:00:00  92.000000   7.000000   63.000000   5.300000  13.275433
# 2016-01-11 17:10:00  92.000000   6.666667   59.166667   5.200000  18.606195
# 2016-01-11 17:20:00  92.000000   6.333333   55.333333   5.100000  28.642668
# 2016-01-11 17:30:00  92.000000   6.000000   51.500000   5.000000  45.410389
# 2016-01-11 17:40:00  92.000000   5.666667   47.666667   4.900000  10.084097
# ...                        ...        ...         ...        ...        ...
# 2016-05-27 17:20:00  55.666667   3.333333   23.666667  13.333333  43.096812
# 2016-05-27 17:30:00  56.000000   3.500000   24.500000  13.300000  49.282940
# 2016-05-27 17:40:00  56.333333   3.666667   25.333333  13.266667  29.199117
# 2016-05-27 17:50:00  56.666667   3.833333   26.166667  13.233333   6.322784
# 2016-05-27 18:00:00  57.000000   4.000000   27.000000  13.200000  34.118851
#
#                            rv2
# date
# 2016-01-11 17:00:00  13.275433
# 2016-01-11 17:10:00  18.606195
# 2016-01-11 17:20:00  28.642668
# 2016-01-11 17:30:00  45.410389
# 2016-01-11 17:40:00  10.084097
# ...                        ...
# 2016-05-27 17:20:00  43.096812
# 2016-05-27 17:30:00  49.282940
# 2016-05-27 17:40:00  29.199117
# 2016-05-27 17:50:00   6.322784
# 2016-05-27 18:00:00  34.118851
#
# [19735 rows x 28 columns]

# %%
data = df.resample('D').sum()

# %%
df = df.resample('D').mean()
df.shape
# Out:
# (138, 28)

# %%
def train_test_split(df):
    
    # compute split point
    end_idx = df.shape[0]* 70 // 100
    
    train_data = df.iloc[1:end_idx, : ]
    test_data = df.iloc[end_idx:, :]
    
    return train_data, test_data

# Split the data into train and test
X_train, X_test = train_test_split(df)

# %%
X_test.shape , X_train.shape
# Out:
# ((42, 28), (95, 28))

# %%
from sklearn.preprocessing import MinMaxScaler
def scale_data(train, test):
    scaler = MinMaxScaler().fit(train)
    return scaler.transform(train), scaler.transform(test), scaler

# %%
X_train, X_test, scaler = scale_data(X_train, X_test)

# %%
def multivariate_splitter(df):

    input_features = []
    ouput_feature = []
    
    len_df = df.shape[0]
    
    for i in range(len_df):
        
        end_idx = i + 15
        
        if end_idx > len_df-15:
            break
            
        input_x , output_y = df[i:end_idx, 1:], df[end_idx: end_idx+15, 0]
        
        input_features.append(input_x)
        ouput_feature.append(output_y)
    
    return np.array(input_features), np.array(ouput_feature)

# %%
X_train, Y_train = multivariate_splitter(X_train)
X_test, Y_test = multivariate_splitter(X_test)

# %%
print('Shape of (training data) input features : %s and ouput feature %s' % (X_train.shape, Y_train.shape))
print('Shape of (testing data) input features : %s and ouput feature %s' % (X_test.shape, Y_test.shape))
# Out:
# Shape of (training data) input features : (66, 15, 27) and ouput feature (66, 15)
# Shape of (testing data) input features : (13, 15, 27) and ouput feature (13, 15)

# %%
import tensorflow as tf
from Energy_Models.LstNet import LSTNetModel
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model = LSTNetModel((15,15,27))

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 15, 27)]     0           []
#
#  reshape_4 (Reshape)            (None, 1, 15, 27)    0           ['input_3[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 1, 15, 27)    2943        ['reshape_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 1, 15, 27)    0           ['conv2d_2[0][0]']
#
#  reshape_5 (Reshape)            (None, 15, 27)       0           ['dropout_4[0][0]']
#
#  gru_2 (GRU)                    [(None, 100),        38700       ['reshape_5[0][0]']
#                                  (None, 100)]
#
#  pre_ar_trans_2 (PreARTrans)    (None, 27, 15)       0           ['input_3[0][0]']
#
#  dropout_5 (Dropout)            (None, 100)          0           ['gru_2[0][1]']
#
#  flatten_5 (Flatten)            (None, 405)          0           ['pre_ar_trans_2[0][0]']
#
#  flatten_4 (Flatten)            (None, 100)          0           ['dropout_5[0][0]']
#
#  dense_7 (Dense)                (None, 1)            406         ['flatten_5[0][0]']
#
#  dense_6 (Dense)                (None, 15)           1515        ['flatten_4[0][0]']
#
#  post_ar_trans_2 (PostARTrans)  (None,)              0           ['dense_7[0][0]',
#                                                                   'input_3[0][0]']
#
#  add_2 (Add)                    (None, 15)           0           ['dense_6[0][0]',
#                                                                   'post_ar_trans_2[0][0]']
#
#  dense_8 (Dense)                (None, 15)           240         ['add_2[0][0]']
#
# ==================================================================================================
# Total params: 43,804
# Trainable params: 43,804
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss ='mse')
history = model.fit(X_train , Y_train, epochs=200, batch_size=64, verbose= 1,validation_split=0.3,callbacks=callback)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 2s 2s/step - loss: 0.0467 - val_loss: 0.0661
# Epoch 2/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0416 - val_loss: 0.0657
# Epoch 3/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0388 - val_loss: 0.0657
# Epoch 4/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0375 - val_loss: 0.0651
# Epoch 5/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0367 - val_loss: 0.0644
# Epoch 6/200
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0368 - val_loss: 0.0638
# Epoch 7/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0360 - val_loss: 0.0632
# Epoch 8/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0356 - val_loss: 0.0628
# Epoch 9/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0350 - val_loss: 0.0624
# Epoch 10/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0344 - val_loss: 0.0621
# Epoch 11/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0342 - val_loss: 0.0618
# Epoch 12/200
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0335 - val_loss: 0.0616
# Epoch 13/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0338 - val_loss: 0.0615
# Epoch 14/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0330 - val_loss: 0.0613
# Epoch 15/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0331 - val_loss: 0.0611
# Epoch 16/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0329 - val_loss: 0.0610
# Epoch 17/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0327 - val_loss: 0.0608
# Epoch 18/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0327 - val_loss: 0.0606
# Epoch 19/200
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0324 - val_loss: 0.0604
# Epoch 20/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0320 - val_loss: 0.0603
# Epoch 21/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0322 - val_loss: 0.0602
# Epoch 22/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0319 - val_loss: 0.0601
# Epoch 23/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0318 - val_loss: 0.0600
# Epoch 24/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0319 - val_loss: 0.0599
# Epoch 25/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0314 - val_loss: 0.0598
# Epoch 26/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0315 - val_loss: 0.0598
# Epoch 27/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0313 - val_loss: 0.0598
# Epoch 28/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0318 - val_loss: 0.0598
# Epoch 29/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0314 - val_loss: 0.0598
# Epoch 30/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0308 - val_loss: 0.0599
# Epoch 31/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0310 - val_loss: 0.0599
# Epoch 32/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0310 - val_loss: 0.0600
# Epoch 33/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0314 - val_loss: 0.0601
# Epoch 34/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0304 - val_loss: 0.0601
# Epoch 35/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0307 - val_loss: 0.0601
# Epoch 36/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0310 - val_loss: 0.0600
# Epoch 37/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0307 - val_loss: 0.0600
# Epoch 38/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0307 - val_loss: 0.0599
# Epoch 39/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0305 - val_loss: 0.0599
# Epoch 40/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0308 - val_loss: 0.0599
# Epoch 41/200
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0306 - val_loss: 0.0599
# Epoch 42/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0306 - val_loss: 0.0599
# Epoch 43/200
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0300 - val_loss: 0.0599
# Epoch 44/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0300 - val_loss: 0.0600
# Epoch 45/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0304 - val_loss: 0.0601
# Epoch 46/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0305 - val_loss: 0.0602
# Epoch 47/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0300 - val_loss: 0.0603
# Epoch 48/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0295 - val_loss: 0.0604
# Epoch 49/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0302 - val_loss: 0.0606
# Epoch 50/200
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0304 - val_loss: 0.0606
# Epoch 51/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0301 - val_loss: 0.0606
# Epoch 52/200
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0297 - val_loss: 0.0605
# Epoch 53/200
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0300 - val_loss: 0.0604
# Epoch 54/200
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0301 - val_loss: 0.0603
# Epoch 55/200
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0300 - val_loss: 0.0602
# Epoch 56/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0296 - val_loss: 0.0602
# Epoch 57/200
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0302 - val_loss: 0.0602
# Epoch 58/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0301 - val_loss: 0.0603

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error, mean_absolute_percentage_error
def root_mean_squared_error(y_true, y_pred):    
    return np.sqrt(mean_squared_error(y_true, y_pred))
def root_mean_squared_log_error(real, predicted):
    sum=0.0
    for x in range(len(predicted)):
        if predicted[x]<0 or real[x]<0: # check for negative values
            continue
        p = np.log(predicted[x]+1)
        r = np.log(real[x]+1)
        sum = sum + (p - r)**2
    return (sum/len(predicted))**0.5
def print_metrics():
    print('Train   RMSE  value   : %.3f ' % root_mean_squared_error(Y_train, model.predict(X_train)))
    print('Train   MSE   value   : %.3f ' % mean_squared_error(Y_train, model.predict(X_train)))
    print('Train   R2    value   : %.3f ' % r2_score(Y_train,model.predict(X_train)))
    print('Train   MAPE  value   : %.3f ' % mean_absolute_percentage_error(Y_train, model.predict(X_train)))
    print('Train   MAE   value   : %.3f ' % mean_absolute_error(Y_train, model.predict(X_train)))
    print('---------------------------------------------')
    print('Test    RMSE  value   : %.3f ' % root_mean_squared_error(Y_test, model.predict(X_test)))
    print('Test    MSE   value   : %.3f ' % mean_squared_error(Y_test, model.predict(X_test)))
    print('Test    R2    value   : %.3f ' % r2_score(Y_test, model.predict(X_test)))
    print('Test    MAPE  value   : %.3f ' % mean_absolute_percentage_error(Y_test, model.predict(X_test)))
    print('Test    MAE   value   : %.3f ' % mean_absolute_error(Y_test, model.predict(X_test)))

# %%
print_metrics()
# Out:
# 3/3 [==============================] - 0s 3ms/step
# Train   RMSE  value   : 0.197
# 3/3 [==============================] - 0s 3ms/step
# Train   MSE   value   : 0.039
# 3/3 [==============================] - 0s 5ms/step
# Train   R2    value   : 0.007
# 3/3 [==============================] - 0s 7ms/step
# Train   MAPE  value   : 3743482242596.677
# 3/3 [==============================] - 0s 4ms/step
# Train   MAE   value   : 0.147
# ---------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# Test    RMSE  value   : 0.198
# 1/1 [==============================] - 0s 23ms/step
# Test    MSE   value   : 0.039
# 1/1 [==============================] - 0s 22ms/step
# Test    R2    value   : -0.074
# 1/1 [==============================] - 0s 24ms/step
# Test    MAPE  value   : 0.430
# 1/1 [==============================] - 0s 27ms/step
# Test    MAE   value   : 0.145

# %%
# Plot of loss vs epoch for train and test dataset
from matplotlib import pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

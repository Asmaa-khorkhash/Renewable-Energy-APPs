# %%
import numpy as np 
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('C:\\Users\\M4\\Desktop\\KAG_energydata_complete.csv',parse_dates=['date'], index_col= 'date')

# %%
df
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:00:00          60      30  19.890000  47.596667  19.200000
# 2016-01-11 17:10:00          60      30  19.890000  46.693333  19.200000
# 2016-01-11 17:20:00          50      30  19.890000  46.300000  19.200000
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 2016-01-11 17:40:00          60      40  19.890000  46.333333  19.200000
# ...                         ...     ...        ...        ...        ...
# 2016-05-27 17:20:00         100       0  25.566667  46.560000  25.890000
# 2016-05-27 17:30:00          90       0  25.500000  46.500000  25.754000
# 2016-05-27 17:40:00         270      10  25.500000  46.596667  25.628571
# 2016-05-27 17:50:00         420      10  25.500000  46.990000  25.414000
# 2016-05-27 18:00:00         430      10  25.500000  46.600000  25.264286
#
#                           RH_2         T3       RH_3         T4       RH_4  \
# date
# 2016-01-11 17:00:00  44.790000  19.790000  44.730000  19.000000  45.566667
# 2016-01-11 17:10:00  44.722500  19.790000  44.790000  19.000000  45.992500
# 2016-01-11 17:20:00  44.626667  19.790000  44.933333  18.926667  45.890000
# 2016-01-11 17:30:00  44.590000  19.790000  45.000000  18.890000  45.723333
# 2016-01-11 17:40:00  44.530000  19.790000  45.000000  18.890000  45.530000
# ...                        ...        ...        ...        ...        ...
# 2016-05-27 17:20:00  42.025714  27.200000  41.163333  24.700000  45.590000
# 2016-05-27 17:30:00  42.080000  27.133333  41.223333  24.700000  45.590000
# 2016-05-27 17:40:00  42.768571  27.050000  41.690000  24.700000  45.730000
# 2016-05-27 17:50:00  43.036000  26.890000  41.290000  24.700000  45.790000
# 2016-05-27 18:00:00  42.971429  26.823333  41.156667  24.700000  45.963333
#
#                      ...         T9     RH_9      T_out  Press_mm_hg  \
# date                 ...
# 2016-01-11 17:00:00  ...  17.033333  45.5300   6.600000        733.5
# 2016-01-11 17:10:00  ...  17.066667  45.5600   6.483333        733.6
# 2016-01-11 17:20:00  ...  17.000000  45.5000   6.366667        733.7
# 2016-01-11 17:30:00  ...  17.000000  45.4000   6.250000        733.8
# 2016-01-11 17:40:00  ...  17.000000  45.4000   6.133333        733.9
# ...                  ...        ...      ...        ...          ...
# 2016-05-27 17:20:00  ...  23.200000  46.7900  22.733333        755.2
# 2016-05-27 17:30:00  ...  23.200000  46.7900  22.600000        755.2
# 2016-05-27 17:40:00  ...  23.200000  46.7900  22.466667        755.2
# 2016-05-27 17:50:00  ...  23.200000  46.8175  22.333333        755.2
# 2016-05-27 18:00:00  ...  23.200000  46.8450  22.200000        755.2
#
#                         RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# date
# 2016-01-11 17:00:00  92.000000   7.000000   63.000000   5.300000  13.275433
# 2016-01-11 17:10:00  92.000000   6.666667   59.166667   5.200000  18.606195
# 2016-01-11 17:20:00  92.000000   6.333333   55.333333   5.100000  28.642668
# 2016-01-11 17:30:00  92.000000   6.000000   51.500000   5.000000  45.410389
# 2016-01-11 17:40:00  92.000000   5.666667   47.666667   4.900000  10.084097
# ...                        ...        ...         ...        ...        ...
# 2016-05-27 17:20:00  55.666667   3.333333   23.666667  13.333333  43.096812
# 2016-05-27 17:30:00  56.000000   3.500000   24.500000  13.300000  49.282940
# 2016-05-27 17:40:00  56.333333   3.666667   25.333333  13.266667  29.199117
# 2016-05-27 17:50:00  56.666667   3.833333   26.166667  13.233333   6.322784
# 2016-05-27 18:00:00  57.000000   4.000000   27.000000  13.200000  34.118851
#
#                            rv2
# date
# 2016-01-11 17:00:00  13.275433
# 2016-01-11 17:10:00  18.606195
# 2016-01-11 17:20:00  28.642668
# 2016-01-11 17:30:00  45.410389
# 2016-01-11 17:40:00  10.084097
# ...                        ...
# 2016-05-27 17:20:00  43.096812
# 2016-05-27 17:30:00  49.282940
# 2016-05-27 17:40:00  29.199117
# 2016-05-27 17:50:00   6.322784
# 2016-05-27 18:00:00  34.118851
#
# [19735 rows x 28 columns]

# %%
data = df.resample('D').sum()

# %%
df = df.resample('D').mean()
df.shape
# Out:
# (138, 28)

# %%
def train_test_split(df):
    
    # compute split point
    end_idx = df.shape[0]* 70 // 100
    
    train_data = df.iloc[1:end_idx, : ]
    test_data = df.iloc[end_idx:, :]
    
    return train_data, test_data

# Split the data into train and test
X_train, X_test = train_test_split(df)

# %%
X_test.shape , X_train.shape
# Out:
# ((42, 28), (95, 28))

# %%
from sklearn.preprocessing import MinMaxScaler
def scale_data(train, test):
    scaler = MinMaxScaler().fit(train)
    return scaler.transform(train), scaler.transform(test), scaler

# %%
X_train, X_test, scaler = scale_data(X_train, X_test)

# %%
def multivariate_splitter(df):

    input_features = []
    ouput_feature = []
    
    len_df = df.shape[0]
    
    for i in range(len_df):
        
        end_idx = i + 15
        
        if end_idx > len_df-15:
            break
            
        input_x , output_y = df[i:end_idx, 1:], df[end_idx: end_idx+15, 0]
        
        input_features.append(input_x)
        ouput_feature.append(output_y)
    
    return np.array(input_features), np.array(ouput_feature)

# %%
X_train, Y_train = multivariate_splitter(X_train)
X_test, Y_test = multivariate_splitter(X_test)

# %%
print('Shape of (training data) input features : %s and ouput feature %s' % (X_train.shape, Y_train.shape))
print('Shape of (testing data) input features : %s and ouput feature %s' % (X_test.shape, Y_test.shape))
# Out:
# Shape of (training data) input features : (66, 15, 27) and ouput feature (66, 15)
# Shape of (testing data) input features : (13, 15, 27) and ouput feature (13, 15)

# %%
import tensorflow as tf
from Energy_Models.Autoformer import AutoFormer
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
model = AutoFormer(15,27,15).getModel()

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 15, 27)]     0           []
#
#  encoder_layer_12 (EncoderLayer  (None, 15, 27)      756         ['input_7[0][0]']
#  )
#
#  tf.__operators__.getitem_23 (S  (None, 27)          0           ['encoder_layer_12[0][0]']
#  licingOpLambda)
#
#  dropout_37 (Dropout)           (None, 27)           0           ['tf.__operators__.getitem_23[0][
#                                                                  0]']
#
#  dense_49 (Dense)               (None, 512)          14336       ['dropout_37[0][0]']
#
#  dropout_38 (Dropout)           multiple             0           ['dense_49[0][0]',
#                                                                   'dense_50[0][0]']
#
#  dense_50 (Dense)               (None, 1024)         525312      ['dropout_38[0][0]']
#
#  dense_51 (Dense)               (None, 512)          524800      ['dropout_38[1][0]']
#
#  dense_48 (Dense)               (None, 15)           7695        ['dense_51[0][0]']
#
# ==================================================================================================
# Total params: 1,072,899
# Trainable params: 1,072,899
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss ='mae')
history = model.fit(X_train , Y_train, epochs=100, batch_size=1, verbose= 1,validation_split=0.2,callbacks=callback)
# Out:
# Epoch 1/100
# 52/52 [==============================] - 7s 51ms/step - loss: 0.1528 - val_loss: 0.2067
# Epoch 2/100
# 52/52 [==============================] - 1s 28ms/step - loss: 0.1396 - val_loss: 0.2030
# Epoch 3/100
# 52/52 [==============================] - 2s 35ms/step - loss: 0.1395 - val_loss: 0.2065
# Epoch 4/100
# 52/52 [==============================] - 2s 33ms/step - loss: 0.1360 - val_loss: 0.2038
# Epoch 5/100
# 52/52 [==============================] - 2s 30ms/step - loss: 0.1334 - val_loss: 0.2017
# Epoch 6/100
# 52/52 [==============================] - 2s 30ms/step - loss: 0.1306 - val_loss: 0.2080
# Epoch 7/100
# 52/52 [==============================] - 2s 30ms/step - loss: 0.1292 - val_loss: 0.2033
# Epoch 8/100
# 52/52 [==============================] - 2s 30ms/step - loss: 0.1237 - val_loss: 0.2064
# Epoch 9/100
# 52/52 [==============================] - 2s 29ms/step - loss: 0.1262 - val_loss: 0.2068
# Epoch 10/100
# 52/52 [==============================] - 1s 25ms/step - loss: 0.1238 - val_loss: 0.2113
# Epoch 11/100
# 52/52 [==============================] - 2s 29ms/step - loss: 0.1245 - val_loss: 0.2097
# Epoch 12/100
# 52/52 [==============================] - 2s 30ms/step - loss: 0.1219 - val_loss: 0.2081
# Epoch 13/100
# 52/52 [==============================] - 1s 29ms/step - loss: 0.1194 - val_loss: 0.2082
# Epoch 14/100
# 52/52 [==============================] - 1s 28ms/step - loss: 0.1143 - val_loss: 0.2098
# Epoch 15/100
# 52/52 [==============================] - 1s 29ms/step - loss: 0.1160 - val_loss: 0.2064
# Epoch 16/100
# 52/52 [==============================] - 1s 28ms/step - loss: 0.1164 - val_loss: 0.2051
# Epoch 17/100
# 52/52 [==============================] - 1s 26ms/step - loss: 0.1185 - val_loss: 0.2038
# Epoch 18/100
# 52/52 [==============================] - 1s 29ms/step - loss: 0.1132 - val_loss: 0.2078
# Epoch 19/100
# 52/52 [==============================] - 1s 29ms/step - loss: 0.1090 - val_loss: 0.2104
# Epoch 20/100
# 52/52 [==============================] - 2s 29ms/step - loss: 0.1103 - val_loss: 0.2090
# Epoch 21/100
# 52/52 [==============================] - 2s 29ms/step - loss: 0.1052 - val_loss: 0.2148
# Epoch 22/100
# 52/52 [==============================] - 2s 30ms/step - loss: 0.1086 - val_loss: 0.2169
# Epoch 23/100
# 52/52 [==============================] - 2s 30ms/step - loss: 0.1048 - val_loss: 0.2210
# Epoch 24/100
# 52/52 [==============================] - 2s 31ms/step - loss: 0.0974 - val_loss: 0.2169
# Epoch 25/100
# 52/52 [==============================] - 1s 27ms/step - loss: 0.1029 - val_loss: 0.2212
# Epoch 26/100
# 52/52 [==============================] - 2s 31ms/step - loss: 0.1004 - val_loss: 0.2147
# Epoch 27/100
# 52/52 [==============================] - 2s 34ms/step - loss: 0.0965 - val_loss: 0.2152
# Epoch 28/100
# 52/52 [==============================] - 2s 30ms/step - loss: 0.0953 - val_loss: 0.2146
# Epoch 29/100
# 52/52 [==============================] - 2s 33ms/step - loss: 0.0891 - val_loss: 0.2154
# Epoch 30/100
# 52/52 [==============================] - 2s 32ms/step - loss: 0.0912 - val_loss: 0.2227
# Epoch 31/100
# 52/52 [==============================] - 2s 36ms/step - loss: 0.0866 - val_loss: 0.2151
# Epoch 32/100
# 52/52 [==============================] - 2s 30ms/step - loss: 0.0903 - val_loss: 0.2208
# Epoch 33/100
# 52/52 [==============================] - 2s 30ms/step - loss: 0.0853 - val_loss: 0.2151
# Epoch 34/100
# 52/52 [==============================] - 1s 20ms/step - loss: 0.0819 - val_loss: 0.2173
# Epoch 35/100
# 52/52 [==============================] - 1s 22ms/step - loss: 0.0852 - val_loss: 0.2138
# Epoch 36/100
# 52/52 [==============================] - 1s 25ms/step - loss: 0.0760 - val_loss: 0.2210
# Epoch 37/100
# 52/52 [==============================] - 2s 32ms/step - loss: 0.0777 - val_loss: 0.2138
# Epoch 38/100
# 52/52 [==============================] - 1s 29ms/step - loss: 0.0745 - val_loss: 0.2206
# Epoch 39/100
# 52/52 [==============================] - 2s 29ms/step - loss: 0.0741 - val_loss: 0.2152
# Epoch 40/100
# 52/52 [==============================] - 1s 28ms/step - loss: 0.0724 - val_loss: 0.2178
# Epoch 41/100
# 52/52 [==============================] - 1s 24ms/step - loss: 0.0701 - val_loss: 0.2141
# Epoch 42/100
# 52/52 [==============================] - 2s 33ms/step - loss: 0.0695 - val_loss: 0.2143
# Epoch 43/100
# 52/52 [==============================] - 2s 36ms/step - loss: 0.0638 - val_loss: 0.2118
# Epoch 44/100
# 52/52 [==============================] - 2s 34ms/step - loss: 0.0711 - val_loss: 0.2158
# Epoch 45/100
# 52/52 [==============================] - 1s 28ms/step - loss: 0.0642 - val_loss: 0.2161
# Epoch 46/100
# 52/52 [==============================] - 2s 32ms/step - loss: 0.0642 - val_loss: 0.2141
# Epoch 47/100
# 52/52 [==============================] - 2s 35ms/step - loss: 0.0649 - val_loss: 0.2189
# Epoch 48/100
# 52/52 [==============================] - 2s 33ms/step - loss: 0.0633 - val_loss: 0.2130
# Epoch 49/100
# 52/52 [==============================] - 2s 32ms/step - loss: 0.0655 - val_loss: 0.2153
# Epoch 50/100
# 52/52 [==============================] - 2s 30ms/step - loss: 0.0595 - val_loss: 0.2158
# Epoch 51/100
# 52/52 [==============================] - 2s 36ms/step - loss: 0.0674 - val_loss: 0.2100
# Epoch 52/100
# 52/52 [==============================] - 2s 33ms/step - loss: 0.0593 - val_loss: 0.2184
# Epoch 53/100
# 52/52 [==============================] - 2s 45ms/step - loss: 0.0545 - val_loss: 0.2135
# Epoch 54/100
# 52/52 [==============================] - 2s 39ms/step - loss: 0.0633 - val_loss: 0.2207
# Epoch 55/100
# 52/52 [==============================] - 2s 45ms/step - loss: 0.0598 - val_loss: 0.2219
# Epoch 56/100
# 52/52 [==============================] - 2s 41ms/step - loss: 0.0594 - val_loss: 0.2112
# Epoch 57/100
# 52/52 [==============================] - 2s 43ms/step - loss: 0.0576 - val_loss: 0.2132
# Epoch 58/100
# 52/52 [==============================] - 2s 46ms/step - loss: 0.0514 - val_loss: 0.2162
# Epoch 59/100
# 52/52 [==============================] - 2s 39ms/step - loss: 0.0495 - val_loss: 0.2177
# Epoch 60/100
# 52/52 [==============================] - 2s 42ms/step - loss: 0.0542 - val_loss: 0.2156
# Epoch 61/100
# 52/52 [==============================] - 2s 31ms/step - loss: 0.0536 - val_loss: 0.2190
# Epoch 62/100
# 52/52 [==============================] - 2s 44ms/step - loss: 0.0591 - val_loss: 0.2150
# Epoch 63/100
# 52/52 [==============================] - 2s 44ms/step - loss: 0.0583 - val_loss: 0.2123
# Epoch 64/100
# 52/52 [==============================] - 2s 47ms/step - loss: 0.0561 - val_loss: 0.2184
# Epoch 65/100
# 52/52 [==============================] - 3s 62ms/step - loss: 0.0524 - val_loss: 0.2129
# Epoch 66/100
# 52/52 [==============================] - 3s 61ms/step - loss: 0.0513 - val_loss: 0.2190
# Epoch 67/100
# 52/52 [==============================] - 3s 57ms/step - loss: 0.0557 - val_loss: 0.2111
# Epoch 68/100
# 52/52 [==============================] - 3s 49ms/step - loss: 0.0561 - val_loss: 0.2091
# Epoch 69/100
# 52/52 [==============================] - 3s 56ms/step - loss: 0.0550 - val_loss: 0.2103

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error, mean_absolute_percentage_error
def root_mean_squared_error(y_true, y_pred):    
    return np.sqrt(mean_squared_error(y_true, y_pred))
def root_mean_squared_log_error(real, predicted):
    sum=0.0
    for x in range(len(predicted)):
        if predicted[x]<0 or real[x]<0: # check for negative values
            continue
        p = np.log(predicted[x]+1)
        r = np.log(real[x]+1)
        sum = sum + (p - r)**2
    return (sum/len(predicted))**0.5
def print_metrics():
    print('Train   RMSE  value   : %.3f ' % root_mean_squared_error(Y_train, model.predict(X_train)))
    print('Train   MSE   value   : %.3f ' % mean_squared_error(Y_train, model.predict(X_train)))
    print('Train   R2    value   : %.3f ' % r2_score(Y_train,model.predict(X_train)))
    print('Train   MAPE  value   : %.3f ' % mean_absolute_percentage_error(Y_train, model.predict(X_train)))
    print('Train   MAE   value   : %.3f ' % mean_absolute_error(Y_train, model.predict(X_train)))
    print('---------------------------------------------')
    print('Test    RMSE  value   : %.3f ' % root_mean_squared_error(Y_test, model.predict(X_test)))
    print('Test    MSE   value   : %.3f ' % mean_squared_error(Y_test, model.predict(X_test)))
    print('Test    R2    value   : %.3f ' % r2_score(Y_test, model.predict(X_test)))
    print('Test    MAPE  value   : %.3f ' % mean_absolute_percentage_error(Y_test, model.predict(X_test)))
    print('Test    MAE   value   : %.3f ' % mean_absolute_error(Y_test, model.predict(X_test)))

# %%
print_metrics()
# Out:
# 3/3 [==============================] - 2s 8ms/step
# Train   RMSE  value   : 0.131
# 3/3 [==============================] - 1s 15ms/step
# Train   MSE   value   : 0.017
# 3/3 [==============================] - 1s 13ms/step
# Train   R2    value   : 0.564
# 3/3 [==============================] - 1s 17ms/step
# Train   MAPE  value   : 216742116614.983
# 3/3 [==============================] - 0s 14ms/step
# Train   MAE   value   : 0.076
# ---------------------------------------------
# 1/1 [==============================] - 1s 717ms/step
# Test    RMSE  value   : 0.213
# 1/1 [==============================] - 1s 580ms/step
# Test    MSE   value   : 0.045
# 1/1 [==============================] - 0s 398ms/step
# Test    R2    value   : -0.259
# 1/1 [==============================] - 1s 526ms/step
# Test    MAPE  value   : 0.544
# 1/1 [==============================] - 0s 469ms/step
# Test    MAE   value   : 0.167

# %%
# Plot of loss vs epoch for train and test dataset
from matplotlib import pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
